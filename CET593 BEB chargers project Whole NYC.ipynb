# %% [markdown]
# # Library

# %%
from beb_chargers.scripts.script_helpers import build_trips_df, \
    build_charger_location_inputs
from beb_chargers.opt.charger_location import ChargerLocationModel
from beb_chargers.gtfs_beb import GTFSData
from beb_chargers.vis import plot_trips_and_terminals, plot_deadhead
from pathlib import Path
import datetime
import pandas as pd
import logging
logging.basicConfig(level=logging.INFO)

# %% [markdown]
# # Parameters

# %%
# Power output of each charger. Note that the model expects a unit of
# kilowatt-hours per minute, so that the amount of energy gained equals
# charging time (in minutes) multiplied by power (in kWh/min). Here, we
# use 450 kW = 450 / 60 kWh/min
chg_pwrs = 450 / 60

# Maximum number of chargers per site. We'll set it to 4 everywhere
n_max = 4

# Cost parameters. See TRC paper for where the values come from.
s_cost = 200000
c_cost = 698447
alpha = 190 * 365 * 12 / 60

# Locate CSV file giving candidate charger sites for this instance
site_fname = Path.cwd().parent / 'beb_chargers' / 'data' / 'test.csv'

# Load candidate charging sites given by Metro and add params as columns
loc_df = pd.read_csv(site_fname)
loc_df['max_chargers'] = n_max
loc_df['kw'] = chg_pwrs * 60
loc_df['fixed_cost'] = s_cost
loc_df['charger_cost'] = c_cost

# Define coordinates of overnight depot at South Base
depot_coords = (40.819197, -73.957060)

# %% [markdown]
# # Data

# %%
# Directory to GTFS files, as a platform-agnostic path
gtfs_dir = Path.cwd().parent / 'beb_chargers' / 'data' / 'gtfs' / 'GTFS'

# Load GTFS data into our custom object
gtfs = GTFSData.from_dir(gtfs_dir)

# %%
# Battery capacity in kWh
battery_cap = 300
# Energy consumption per mile for all buses (we'll assume it's the same
# for all buses here)
kwh_per_mi = 3

# %%
import csv
import random

# %%
import csv
import random

def read_routes_file(filename):
    """
    Reads the routes file and returns a list of route IDs that start with 'M'.
    
    Args:
        filename (str): Path to the CSV file containing route IDs.
    
    Returns:
        list: Filtered list of route IDs where the first letter is 'M'.
    """
    route_ids = []
    with open(filename, 'r', encoding='utf-8') as f:
        reader = csv.DictReader(f)
        for row in reader:
            # if row['route_id'].startswith('M'):  # Filter routes that start with 'M'
            #    route_ids.append(row['route_id'])
            route_ids.append(row['route_id'])
    return route_ids

def random_select_routes(route_ids, percentage=.1):
    """
    Randomly selects a subset of routes from the filtered list.
    
    Args:
        route_ids (list): List of filtered route IDs.
        percentage (float): Percentage of routes to select per iteration.
    
    Returns:
        list: Randomly selected route IDs.
    """
    num_to_select = round(len(route_ids) * percentage)
    return random.sample(route_ids, num_to_select) if route_ids else []

def main():
    filename = Path.cwd().parent / 'beb_chargers' / 'data' / 'gtfs' / 'GTFS' / 'routes.txt'
    num_iterations = 10  # Define the number of iterations
    
    route_ids = read_routes_file(filename)  # Read and filter routes
    print(f"Total number of routes starting with 'M': {len(route_ids)}")
    
    all_results = []
    
    for i in range(num_iterations):
        selected = random_select_routes(route_ids)  # Select 20% of the filtered routes
        all_results.append(selected)
        print(f"\nIteration {i+1}:")
        print(f"Selected {len(selected)} routes: {selected}")
    
    return all_results

if __name__ == "__main__":
    random.seed(42)  # Ensure reproducibility
    
    # Run the main process
    results = main()
    
    print("\nFinal 2D array of selected route_ids:")
    for i, row in enumerate(results):
        print(f"Row {i+1}: {row}")
# Out:
# Total number of routes starting with 'M': 314
#
# Iteration 1:
# Selected 31 routes: ['B92', 'B26', 'M125', 'M4', 'OHAS', 'BX12+', 'B83', 'L90', 'B68', 'B93', 'SIM7', 'B35', 'B32', 'B70', 'MVAS', 'CSAS', 'S89', 'Q97', 'B3', 'Q108', 'BX41+', 'SIM5', 'MQAS', 'SIM31', 'BX90', 'M14A+', 'B13', 'BX20', 'Q15A', 'BX19', 'GHAS']
#
# Iteration 2:
# Selected 31 routes: ['Q13', 'B83', 'B70', 'Q56', 'B8', 'Q30', 'Q17', 'Q121', 'M104', 'B41', 'S40', 'J99', 'BX6+', 'Q55', 'B63', 'Q92', 'M31', 'Q32', 'F1', 'BX39', 'B57', 'B42', 'FBAS', 'M22', 'CSAS', 'B82+', 'M14A+', 'SIM33C', 'Q36', 'BX22', 'Q44+']
#
# Iteration 3:
# Selected 31 routes: ['Q27', 'SHNRD', 'M106', 'B6', 'B106', 'BX27', 'D99', 'M4', 'BX22', 'S42', 'Q56', 'M116', 'Q95', 'MQAS', 'Q1', 'B46', 'GAAS', 'B35', 'M79+', 'Q110', 'M11', 'B52', 'SIR5', 'Q96', 'S81', 'Q84', 'SIM35', 'BX15', 'M104', 'BX12+', 'M5']
#
# Iteration 4:
# Selected 31 routes: ['Q108', 'J90', 'M103', 'S96B3', 'SIM9', 'S96B2', 'Q88', 'Q32', 'MQAS', 'BX12', 'S91', 'S76', 'B7', 'B43', 'B91A', 'BX18A', 'BX20', 'SIM7', 'B101', 'B49', 'Q76', 'Q58', 'S48', 'X63', 'M8', 'Q93', 'B15', 'BX3', 'J99', 'M106', 'Q15A']
#
# Iteration 5:
# Selected 31 routes: ['B92', 'M31', 'SIM15', 'BX2', 'SIM33C', 'B11', 'M103', 'S84', 'BX31', 'S90', 'B9', 'M34A+', 'B106', 'BX41+', 'BX18A', 'Q48', 'BX21', 'B90', 'X64', 'B1', 'BX92', 'M99', 'S66', 'B20', 'Q32', 'M57', 'M1', 'B46+', 'M2', 'Q96', 'B63']
#
# Iteration 6:
# Selected 31 routes: ['B67', 'S61', 'B57', 'X68', 'BX7', 'BX8', 'S54', 'Q90', 'BX24', 'M104', 'X63', 'Q109', 'SIM7', 'SIR5', 'B90', 'BX42', 'M66', 'Q88', 'Q48', 'SIM23', 'S96', 'SIM33', 'BX5', 'M5', 'ENAS', 'B49', 'Q15', 'B24', 'BX90', 'Q93', 'GAAS']
#
# Iteration 7:
# Selected 31 routes: ['BX90', 'MQAS', 'B13', 'B6', 'B47', 'GAAS', 'B54', 'B35', 'Q4', 'S94', 'WFAS', 'M14A+', 'S61', 'SHUT5', 'B90', 'BX1', 'L1227', 'F1', 'S53', 'M3', 'SIM2', 'BX38', 'B74', 'B8', 'SIM10', 'Q27', 'SIM7', 'SIM3C', 'S48', 'B45', 'B82']
#
# Iteration 8:
# Selected 31 routes: ['B48', 'SIM1', 'Q15', 'B91', 'M7', 'BX39', 'BX38', 'J99', 'SIM31', 'BX12+', 'SIM7', 'BX33', 'M14A+', 'S42', 'B61', 'SIM25', 'Q90', 'B82', 'B44', 'B90', 'B17', 'B70', 'WFAS', 'BX25', 'SIM2', 'S61', 'S57', 'SHUT5', 'Q110', 'B47', 'BX24']
#
# Iteration 9:
# Selected 31 routes: ['Q56', 'B11', 'Q78', 'M104', 'SIM33C', 'M20', 'SIM7', 'Q94', 'S62', 'BX19', 'BX38', 'M34+', 'MVAS', 'B46+', 'M191', 'D90', 'B48', 'M72', 'B44', 'S96B3', 'S55', 'S86', 'X64', 'BX2', 'S91', 'B64', 'BX35', 'B57', 'B99', 'B54', 'KBAS']
#
# Iteration 10:
# Selected 31 routes: ['SIM1', 'BX5', 'JBLAF', 'M5', 'M191', 'B99', 'B39', 'B64', 'SIM5', 'S96B2', 'B98', 'X28', 'M79+', 'M102', 'BX99', 'M72', 'M1', 'M104', 'Q84', 'BX1', 'M35', 'SIM35', 'B60', 'B14', 'B96', 'B82+', 'J90', 'SHUT5', 'S90', 'Q20B', 'B57']
#
# Final 2D array of selected route_ids:
# Row 1: ['B92', 'B26', 'M125', 'M4', 'OHAS', 'BX12+', 'B83', 'L90', 'B68', 'B93', 'SIM7', 'B35', 'B32', 'B70', 'MVAS', 'CSAS', 'S89', 'Q97', 'B3', 'Q108', 'BX41+', 'SIM5', 'MQAS', 'SIM31', 'BX90', 'M14A+', 'B13', 'BX20', 'Q15A', 'BX19', 'GHAS']
# Row 2: ['Q13', 'B83', 'B70', 'Q56', 'B8', 'Q30', 'Q17', 'Q121', 'M104', 'B41', 'S40', 'J99', 'BX6+', 'Q55', 'B63', 'Q92', 'M31', 'Q32', 'F1', 'BX39', 'B57', 'B42', 'FBAS', 'M22', 'CSAS', 'B82+', 'M14A+', 'SIM33C', 'Q36', 'BX22', 'Q44+']
# Row 3: ['Q27', 'SHNRD', 'M106', 'B6', 'B106', 'BX27', 'D99', 'M4', 'BX22', 'S42', 'Q56', 'M116', 'Q95', 'MQAS', 'Q1', 'B46', 'GAAS', 'B35', 'M79+', 'Q110', 'M11', 'B52', 'SIR5', 'Q96', 'S81', 'Q84', 'SIM35', 'BX15', 'M104', 'BX12+', 'M5']
# Row 4: ['Q108', 'J90', 'M103', 'S96B3', 'SIM9', 'S96B2', 'Q88', 'Q32', 'MQAS', 'BX12', 'S91', 'S76', 'B7', 'B43', 'B91A', 'BX18A', 'BX20', 'SIM7', 'B101', 'B49', 'Q76', 'Q58', 'S48', 'X63', 'M8', 'Q93', 'B15', 'BX3', 'J99', 'M106', 'Q15A']
# Row 5: ['B92', 'M31', 'SIM15', 'BX2', 'SIM33C', 'B11', 'M103', 'S84', 'BX31', 'S90', 'B9', 'M34A+', 'B106', 'BX41+', 'BX18A', 'Q48', 'BX21', 'B90', 'X64', 'B1', 'BX92', 'M99', 'S66', 'B20', 'Q32', 'M57', 'M1', 'B46+', 'M2', 'Q96', 'B63']
# Row 6: ['B67', 'S61', 'B57', 'X68', 'BX7', 'BX8', 'S54', 'Q90', 'BX24', 'M104', 'X63', 'Q109', 'SIM7', 'SIR5', 'B90', 'BX42', 'M66', 'Q88', 'Q48', 'SIM23', 'S96', 'SIM33', 'BX5', 'M5', 'ENAS', 'B49', 'Q15', 'B24', 'BX90', 'Q93', 'GAAS']
# Row 7: ['BX90', 'MQAS', 'B13', 'B6', 'B47', 'GAAS', 'B54', 'B35', 'Q4', 'S94', 'WFAS', 'M14A+', 'S61', 'SHUT5', 'B90', 'BX1', 'L1227', 'F1', 'S53', 'M3', 'SIM2', 'BX38', 'B74', 'B8', 'SIM10', 'Q27', 'SIM7', 'SIM3C', 'S48', 'B45', 'B82']
# Row 8: ['B48', 'SIM1', 'Q15', 'B91', 'M7', 'BX39', 'BX38', 'J99', 'SIM31', 'BX12+', 'SIM7', 'BX33', 'M14A+', 'S42', 'B61', 'SIM25', 'Q90', 'B82', 'B44', 'B90', 'B17', 'B70', 'WFAS', 'BX25', 'SIM2', 'S61', 'S57', 'SHUT5', 'Q110', 'B47', 'BX24']
# Row 9: ['Q56', 'B11', 'Q78', 'M104', 'SIM33C', 'M20', 'SIM7', 'Q94', 'S62', 'BX19', 'BX38', 'M34+', 'MVAS', 'B46+', 'M191', 'D90', 'B48', 'M72', 'B44', 'S96B3', 'S55', 'S86', 'X64', 'BX2', 'S91', 'B64', 'BX35', 'B57', 'B99', 'B54', 'KBAS']
# Row 10: ['SIM1', 'BX5', 'JBLAF', 'M5', 'M191', 'B99', 'B39', 'B64', 'SIM5', 'S96B2', 'B98', 'X28', 'M79+', 'M102', 'BX99', 'M72', 'M1', 'M104', 'Q84', 'BX1', 'M35', 'SIM35', 'B60', 'B14', 'B96', 'B82+', 'J90', 'SHUT5', 'S90', 'Q20B', 'B57']

# %%
results = main()
# Out:
# Total number of routes starting with 'M': 314
#
# Iteration 1:
# Selected 31 routes: ['M4', 'Q44+', 'M15+', 'BX2', 'SIM23', 'L92', 'M42', 'B111', 'X63', 'B14', 'Q93', 'M35', 'B84', 'BX10', 'M104', 'BX4', 'B9', 'BX19', 'M12', 'M15', 'Q121', 'SHNRD', 'Q16', 'BX99', 'S89', 'S66', 'M8', 'B44+', 'B70', 'SIM7', 'M141A']
#
# Iteration 2:
# Selected 31 routes: ['B41', 'B11', 'Q5', 'BX9', 'M103', 'BX21', 'SIM25', 'Q92', 'SIM8X', 'Q108', 'B14', 'B92', 'B61', 'BX18', 'L90', 'B37', 'Q44+', 'S96B2', 'BX17', 'SIM10', 'BX8', 'B4', 'M57', 'Q36', 'B39', 'Q30', 'SHNRD', 'M7', 'B83', 'Q27', 'Q107']
#
# Iteration 3:
# Selected 31 routes: ['SIM2', 'BX19', 'WFAS', 'BX22', 'BX30', 'SIM4', 'B26', 'BX31', 'Q5', 'SIM3C', 'M7', 'M106', 'BX20', 'B91', 'Q58', 'B38', 'S51', 'OFAS', 'BX42', 'S40', 'Q24', 'M55', 'FBAS', 'OHAS', 'BX39', 'Q88', 'Q3', 'M14A+', 'B57', 'S91', 'J99']
#
# Iteration 4:
# Selected 31 routes: ['Q4', 'B31', 'BX4', 'M102', 'BX31', 'S96B1', 'M104', 'B38', 'B91', 'B101', 'SIM15', 'Q17', 'M72', 'SIM22', 'Q109', 'S92', 'Q76', 'F1', 'BX38', 'M10', 'B41', 'B1', 'X27', 'J90', 'BX41', 'Q36', 'SIM10', 'B57', 'BX6+', 'M35', 'S90']
#
# Iteration 5:
# Selected 31 routes: ['M60+', 'SIM3', 'Q2', 'SIM1', 'M34+', 'Q93', 'BX8', 'BX39', 'SIM6', 'Q56', 'BX29', 'JBLAF', 'M42', 'SIM1C', 'M90', 'B1', 'M50', 'M20', 'SHNRD', 'SIM10', 'M191', 'Q109', 'M98', 'S46', 'SIM25', 'SHUT5', 'S92', 'S53', 'BX26', 'B67', 'M15+']
#
# Iteration 6:
# Selected 31 routes: ['S94', 'Q12', 'B70', 'KBAS', 'M60+', 'ENAS', 'BX41+', 'BX17', 'B26', 'B42', 'M4', 'S54', 'BX95', 'B60', 'SIM34', 'SIM4X', 'L0202', 'BX40', 'Q59', 'S78', 'Q88', 'M3', 'B12', 'B9', 'SIM8', 'MQAS', 'BX30', 'S98', 'S44', 'B44', 'Q95']
#
# Iteration 7:
# Selected 31 routes: ['M7', 'BX6', 'SIM34', 'BX10', 'S44', 'X64', 'Q107', 'B99', 'M86+', 'SIM25', 'B111', 'S89', 'SIM8X', 'M90', 'SIM30', 'BX20', 'S54', 'SIM32', 'M101', 'M5', 'M141A', 'X27', 'S61', 'M1', 'M125', 'SIM24', 'B62', 'M20', 'KBAS', 'M12', 'Q12']
#
# Iteration 8:
# Selected 31 routes: ['M96', 'B90', 'B64', 'BX12', 'BX18B', 'JGAS', 'Q59', 'BX18A', 'SHUT5', 'B49', 'SIM4X', 'SIM2', 'Q4', 'D90', 'S46', 'B48', 'EBUS', 'SIM6', 'Q78', 'S96B3', 'B24', 'L0202', 'Q56', 'S55', 'B13', 'Q26', 'M34A+', 'SIM5', 'J90', 'L90', 'Q97']
#
# Iteration 9:
# Selected 31 routes: ['MQAS', 'S62', 'M12', 'SIM22', 'S61', 'B31', 'Q78', 'Q13', 'SIM1C', 'BX24', 'S48', 'BX8', 'D99', 'B3', 'Q83', 'B94', 'B96', 'B65', 'SIM9', 'BX11', 'S42', 'BX33', 'B44', 'M102', 'Q56', 'Q2', 'SIR5', 'SIM33C', 'M14A+', 'SIM6', 'M9']
#
# Iteration 10:
# Selected 31 routes: ['B64', 'S51', 'B20', 'B90', 'B44+', 'Q24', 'OHAS', 'B57', 'B39', 'B32', 'M5', 'BX42', 'B24', 'BX18A', 'M1', 'BX7', 'S53', 'BX3', 'B96', 'MVAS', 'S46', 'M100', 'Q43', 'BX25', 'Q109', 'BX22', 'M66', 'B91', 'M191', 'B3', 'L0202']

# %%
# All routes included in analysis
beb_routes = [
    'M1', 'M2', 'M3', 'M4', 'M5', 'M7', 'M8', 'M9', 'M10',
    'M100', 'M101', 'M102', 'M103', 'M104',
    'M14A-SBS', 'M14D-SBS', 'M15-SBS', 'M60-SBS',
    'Q30', 'Bx18B', 'Bx41-SBS', 'Bx36', 'B44-SBS',
    'B52', 'B74', 'X37', 'B111'
]
beb_routes = [str(r) for r in beb_routes]

beb_routes = results[0]

# %% [markdown]
# import csv
# import random
#
# def read_routes_file(filename):
#     """
#     Read routes file and return route_ids list
#     Args:
#         filename: CSV path
#     Returns:
#         route_ids list
#     """
#     route_ids = []
#     with open(filename, 'r', encoding='utf-8') as f:
#         reader = csv.DictReader(f)
#         for row in reader:
#             route_ids.append(row['route_id'])
#     return route_ids
#
# def filter_m_routes(route_ids):
#     """
#     Filter routes that start with 'M'
#     Args:
#         route_ids: list of all route IDs
#     Returns:
#         list of route IDs starting with 'M'
#     """
#     return [route for route in route_ids if route.startswith('M')]
#
# def random_select_routes_with_m_first(route_ids, percentage=0.1):
#     """
#     Select routes with first one being M-route
#     Args:
#         route_ids: all routes ID
#         percentage: percentage to select
#     Returns:
#         selected routes ID list starting with an M-route
#     """
#     # Separate M routes and non-M routes
#     m_routes = filter_m_routes(route_ids)
#     non_m_routes = [r for r in route_ids if not r.startswith('M')]
#
#     if not m_routes:
#         raise ValueError("No M-routes found in the input data")
#
#     # Calculate how many additional routes to select after M-route
#     total_to_select = round(len(route_ids) * percentage)
#     remaining_to_select = total_to_select - 1  # -1 because we'll select one M-route
#
#     # Select one M-route for the first position
#     selected_routes = [random.choice(m_routes)]
#
#     # Select remaining routes from all available routes (excluding the selected M-route)
#     available_routes = [r for r in route_ids if r != selected_routes[0]]
#
#     # Randomly select the remaining routes
#     for _ in range(remaining_to_select):
#         if not available_routes:
#             break
#         idx = random.randrange(len(available_routes))
#         selected_routes.append(available_routes.pop(idx))
#
#     return selected_routes
#
# def main():
#     filename = Path.cwd().parent / 'beb_chargers' / 'data' / 'gtfs' / 'GTFS' / 'routes.txt'
#     num_iterations = 10
#
#     route_ids = read_routes_file(filename)
#     print(f"Total number of routes: {len(route_ids)}")
#     print(f"Number of M-routes: {len(filter_m_routes(route_ids))}")
#
#     all_results = []
#
#     for i in range(num_iterations):
#         selected = random_select_routes_with_m_first(route_ids)
#         all_results.append(selected)
#         print(f"\nIteration {i+1}:")
#         print(f"Selected {len(selected)} routes: {selected}")
#         print(f"First route starts with 'M': {selected[0].startswith('M')}")
#
#     return all_results
#
# if __name__ == "__main__":
#     random.seed(42)
#
#     # Run main program
#     results = main()
#
#     print("\nFinal 2D array of selected route_ids:")
#     for i, row in enumerate(results):
#         print(f"Row {i+1}: {row}")

# %%
# We'll run analysis for March 28, 2024
ocl_date = datetime.datetime(2025, 3, 14)
# Call helper function to build up DF
beb_trips = build_trips_df(
    gtfs=gtfs,
    date=ocl_date,
    routes=beb_routes,
    depot_coords=depot_coords,
    add_depot_dh=True,
    add_kwh_per_mi=False,
    add_durations=False,
    routes_60=[]
)
# Add a column giving energy consumption for each trip
beb_trips['kwh_per_mi'] = kwh_per_mi
# Out:
# INFO:gtfs_data:OSM request: 30 origins, 35 destinations (1050 total routes)
# INFO:gtfs_data:OpenRouteService matrix returned in 1.00 seconds.

# %%
beb_trips
# Out:
#                                  trip_id route_id          service_id  \
# 0       OH_A5-Saturday-BM-141800_M15_201      M15   OH_A5-Saturday-BM
# 1      MV_A5-Saturday-BM-139500_M104_101     M104   MV_A5-Saturday-BM
# 2      OH_A5-Weekday-SDon-006000_M15_201      M15  OH_A5-Weekday-SDon
# 3      OH_A5-Weekday-SDon-012000_M15_201      M15  OH_A5-Weekday-SDon
# 4      OH_A5-Weekday-SDon-018000_M15_201      M15  OH_A5-Weekday-SDon
# ...                                  ...      ...                 ...
# 2260   QV_A5-Weekday-SDon-104500_X63_757      X63  QV_A5-Weekday-SDon
# 2261   QV_A5-Weekday-SDon-106000_X63_758      X63  QV_A5-Weekday-SDon
# 2262   QV_A5-Weekday-SDon-110000_X63_759      X63  QV_A5-Weekday-SDon
# 2263   QV_A5-Weekday-SDon-114000_X63_760      X63  QV_A5-Weekday-SDon
# 2264  QV_A5-Weekday-SDon-112000_MISC_254      X63  QV_A5-Weekday-SDon
#
#       block_id  shape_id route  route_type                         route_desc  \
# 0     36440938   M150023   M15           3                via 1st Av / 2nd Av
# 1     36441665  M1040167  M104           3              via Broadway / 8th Av
# 2     36441933   M150044   M15           3                via 1st Av / 2nd Av
# 3     36441933   M150023   M15           3                via 1st Av / 2nd Av
# 4     36441933   M150044   M15           3                via 1st Av / 2nd Av
# ...        ...       ...   ...         ...                                ...
# 2260  36882921   X630036   X63           3  via Merrick Bl / Francis Lewis Bl
# 2261  36882922   X630036   X63           3  via Merrick Bl / Francis Lewis Bl
# 2262  36882923   X630036   X63           3  via Merrick Bl / Francis Lewis Bl
# 2263  36882924   X630036   X63           3  via Merrick Bl / Francis Lewis Bl
# 2264  36882925   X630036   X63           3  via Merrick Bl / Francis Lewis Bl
#
#               start_time            end_time  trip_idx  start_lat  start_lon  \
# 0    2025-03-14 23:38:00 2025-03-15 00:39:00         0  40.803182 -73.932486
# 1    2025-03-14 23:15:00 2025-03-14 23:56:00         0  40.814222 -73.953091
# 2    2025-03-14 01:00:00 2025-03-14 01:43:00         0  40.701481 -74.012461
# 3    2025-03-14 02:00:00 2025-03-14 02:46:00         1  40.803182 -73.932486
# 4    2025-03-14 03:00:00 2025-03-14 03:43:00         2  40.701481 -74.012461
# ...                  ...                 ...       ...        ...        ...
# 2260 2025-03-14 17:25:00 2025-03-14 19:17:00         0  40.737263 -73.979386
# 2261 2025-03-14 17:40:00 2025-03-14 19:31:00         0  40.737263 -73.979386
# 2262 2025-03-14 18:20:00 2025-03-14 20:05:00         0  40.737263 -73.979386
# 2263 2025-03-14 19:00:00 2025-03-14 20:28:00         0  40.737263 -73.979386
# 2264 2025-03-14 18:40:00 2025-03-14 20:15:00         0  40.737263 -73.979386
#
#         end_lat    end_lon  total_dist  duration_sched  60_dummy  kwh_per_mi
# 0     40.701549 -74.012199   20.429058            61.0         0           3
# 1     40.756384 -73.989832   11.766449            41.0         0           3
# 2     40.803102 -73.932299   18.574302            43.0         0           3
# 3     40.701549 -74.012199    8.641575            46.0         0           3
# 4     40.803102 -73.932299    8.609989            43.0         0           3
# ...         ...        ...         ...             ...       ...         ...
# 2260  40.652763 -73.736869   51.960957           112.0         0           3
# 2261  40.652763 -73.736869   51.960957           111.0         0           3
# 2262  40.652763 -73.736869   51.960957           105.0         0           3
# 2263  40.652763 -73.736869   51.960957            88.0         0           3
# 2264  40.652763 -73.736869   51.960957            95.0         0           3
#
# [2265 rows x 19 columns]

# %%
# Record how many trips and blocks are active on our specified routes on this day
logging.info(
    '{}: There are {} total trips to be served by {} BEB blocks.'.format(
        ocl_date.strftime('%m/%d/%y'), len(beb_trips), beb_trips['block_id'].nunique()
    )
)
# Out:
# INFO:root:03/14/25: There are 2265 total trips to be served by 336 BEB blocks.

# %%
# Create a map of the problem instance
inst_map = plot_trips_and_terminals(
    beb_trips, loc_df, gtfs.shapes_df, 'light'
)
# These config params make map downloads higher resolution
config = {
    'toImageButtonOptions': {
        'format': 'png',
        'scale': 3
    }
}
inst_map.show(config=config)

# %%
opt_kwargs = build_charger_location_inputs(
    gtfs=gtfs,
    trips_df=beb_trips,
    chargers_df=loc_df,
    depot_coords=depot_coords,
    battery_cap=battery_cap
)
# Out:
# INFO:gtfs_data:OSM request: 21 origins, 38 destinations (798 total routes)
# INFO:gtfs_data:OpenRouteService matrix returned in 0.95 seconds.
# INFO:gtfs_data:OSM request: 38 origins, 24 destinations (912 total routes)
# INFO:gtfs_data:OpenRouteService matrix returned in 0.95 seconds.
# INFO:gtfs_data:OSM request: 39 origins, 45 destinations (1755 total routes)
# INFO:gtfs_data:OpenRouteService matrix returned in 1.07 seconds.

# %%
# this is the dictionary
type (opt_kwargs)
# Out:
# dict

# %%
# Create instance of charger location model based on those inputs
clm = ChargerLocationModel(**opt_kwargs)
# Solve the model with zero optimality gap
clm.solve(alpha=alpha, opt_gap=0, bu_kwh=battery_cap)
# Out:
# INFO:charger_location:Number of blocks that require charging: 166
# INFO:charger_location:Number of trips in charging blocks: 1389
# INFO:charger_location:Number of infeasible blocks: 132
# INFO:charger_location:Infeasible block IDs: ['36459509', '36459510', '36459511', '36459512', '36459517', '36459520', '36459521', '36459522', '36459523', '36459537', '36459538', '36459692', '36459693', '36459694', '36459695', '36459696', '36459697', '36459698', '36459699', '36459700', '36459701', '36459702', '36459703', '36459704', '36459705', '36459706', '36459707', '36459708', '36459709', '36459710', '36459711', '36459712', '36459713', '36459714', '36459715', '36459716', '36459717', '36459718', '36459719', '36459720', '36459722', '36459723', '36459724', '36461209', '36461210', '36461211', '36461213', '36461214', '36461215', '36461216', '36461217', '36461218', '36461219', '36461220', '36461221', '36461222', '36461224', '36461258', '36461259', '36461261', '36461262', '36461263', '36461264', '36461265', '36461266', '36461267', '36461268', '36461272', '36461274', '36822238', '36822459', '36822485', '36822486', '36822487', '36822488', '36822489', '36822490', '36822491', '36822492', '36822493', '36822494', '36822508', '36824044', '36824045', '36824046', '36824047', '36824048', '36824049', '36824050', '36824051', '36824089', '36824090', '36824092', '36824093', '36824096', '36824100', '36824101', '36824102', '36825690', '36825696', '36825698', '36825699', '36825700', '36825701', '36825703', '36825704', '36825705', '36825706', '36825707', '36825708', '36825709', '36825984', '36825985', '36825986', '36825987', '36825988', '36825989', '36825990', '36825991', '36825992', '36825993', '36825994', '36825995', '36825996', '36826000', '36826001', '36826002', '36826003', '36826077', '36826147', '36826270', '36826280']
# INFO:charger_location:Number of trips in infeasible blocks: 603
# INFO:charger_location:Time for heuristic runs: 211.28 seconds
# INFO:charger_location:Average number of backups: 171.76
# INFO:charger_location:Minimum number of backups: 169
#
# INFO:charger_location:Mean Conflict set size: 1.44
# INFO:gurobipy:Set parameter Username
# INFO:gurobipy:Set parameter LicenseID to value 2608727
# INFO:gurobipy:Academic license - for non-commercial use only - expires 2026-01-12
# INFO:gurobipy:Read LP format model from file C:\Users\chris\AppData\Local\Temp\tmparfg9yff.pyomo.lp
# INFO:gurobipy:Reading time = 0.06 seconds
# INFO:gurobipy:x1: 9810 rows, 8630 columns, 34994 nonzeros
# INFO:gurobipy:Set parameter MIPGap to value 0
# INFO:gurobipy:Set parameter MIPFocus to value 3
# INFO:gurobipy:Set parameter Method to value 1
# INFO:gurobipy:Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (win64 - Windows 11.0 (26100.2))
# INFO:gurobipy:
# INFO:gurobipy:CPU model: 13th Gen Intel(R) Core(TM) i5-13450HX, instruction set [SSE2|AVX|AVX2]
# INFO:gurobipy:Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
# INFO:gurobipy:
# INFO:gurobipy:Non-default parameters:
# INFO:gurobipy:MIPGap  0
# INFO:gurobipy:Method  1
# INFO:gurobipy:MIPFocus  3
# INFO:gurobipy:
# INFO:gurobipy:Optimize a model with 9810 rows, 8630 columns and 34994 nonzeros
# INFO:gurobipy:Model fingerprint: 0xd70b5f1b
# INFO:gurobipy:Variable types: 4476 continuous, 4154 integer (4054 binary)
# INFO:gurobipy:Coefficient statistics:
# INFO:gurobipy:  Matrix range     [2e-01, 3e+03]
# INFO:gurobipy:  Objective range  [1e+04, 1e+07]
# INFO:gurobipy:  Bounds range     [1e+00, 1e+00]
# INFO:gurobipy:  RHS range        [3e-01, 5e+02]
# INFO:gurobipy:Presolve removed 8686 rows and 7735 columns
# INFO:gurobipy:Presolve time: 0.06s
# INFO:gurobipy:Presolved: 1124 rows, 895 columns, 3871 nonzeros
# INFO:gurobipy:Variable types: 497 continuous, 398 integer (398 binary)
# INFO:gurobipy:Found heuristic solution: objective 2.891829e+07
# INFO:gurobipy:Found heuristic solution: objective 2.558385e+07
# INFO:gurobipy:Found heuristic solution: objective 2.220758e+07
# INFO:gurobipy:Root relaxation presolve removed 3 rows and 3 columns
# INFO:gurobipy:Root relaxation presolved: 1121 rows, 892 columns, 3868 nonzeros
# INFO:gurobipy:
# INFO:gurobipy:
# INFO:gurobipy:Root relaxation: objective 9.729883e+06, 571 iterations, 0.01 seconds (0.01 work units)
# INFO:gurobipy:
# INFO:gurobipy:    Nodes    |    Current Node    |     Objective Bounds      |     Work
# INFO:gurobipy: Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
# INFO:gurobipy:
# INFO:gurobipy:     0     0 9729883.04    0   32 2.2208e+07 9729883.04  56.2%     -    0s
# INFO:gurobipy:H    0     0                    1.352802e+07 9729883.04  28.1%     -    0s
# INFO:gurobipy:H    0     0                    1.226511e+07 9729883.04  20.7%     -    0s
# INFO:gurobipy:H    0     0                    1.194085e+07 9729883.04  18.5%     -    0s
# INFO:gurobipy:H    0     0                    1.183276e+07 9729883.04  17.8%     -    0s
# INFO:gurobipy:H    0     0                    1.129231e+07 9729883.04  13.8%     -    0s
# INFO:gurobipy:     0     0 1.1055e+07    0   40 1.1292e+07 1.1055e+07  2.10%     -    0s
# INFO:gurobipy:     0     0 1.1055e+07    0   20 1.1292e+07 1.1055e+07  2.10%     -    0s
# INFO:gurobipy:H    0     0                    1.118422e+07 1.1055e+07  1.15%     -    0s
# INFO:gurobipy:     0     0 1.1092e+07    0    8 1.1184e+07 1.1092e+07  0.83%     -    0s
# INFO:gurobipy:
# INFO:gurobipy:Explored 1 nodes (799 simplex iterations) in 0.22 seconds (0.15 work units)
# INFO:gurobipy:Thread count was 16 (of 16 available processors)
# INFO:gurobipy:
# INFO:gurobipy:Solution count 10: 1.11842e+07 1.11842e+07 1.11842e+07 ... 2.22076e+07
# INFO:gurobipy:
# INFO:gurobipy:Optimal solution found (tolerance 0.00e+00)
# INFO:gurobipy:Best objective 1.118422343500e+07, best bound 1.118422343500e+07, gap 0.0000%
# INFO:charger_location:Time for initial model solve: 0.93 seconds
# INFO:charger_location:Incumbent model has 9 queue prevention constraints
# INFO:gurobipy:Read LP format model from file C:\Users\chris\AppData\Local\Temp\tmpm1cqn26f.pyomo.lp
# INFO:gurobipy:Reading time = 0.06 seconds
# INFO:gurobipy:x1: 9819 rows, 8630 columns, 35023 nonzeros
# INFO:gurobipy:Read MIP start from file C:\Users\chris\AppData\Local\Temp\tmpkg5bvj0o.gurobi.mst
# INFO:gurobipy:Set parameter MIPGap to value 0
# INFO:gurobipy:Set parameter MIPFocus to value 3
# INFO:gurobipy:Set parameter Method to value 1
# INFO:gurobipy:Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (win64 - Windows 11.0 (26100.2))
# INFO:gurobipy:
# INFO:gurobipy:CPU model: 13th Gen Intel(R) Core(TM) i5-13450HX, instruction set [SSE2|AVX|AVX2]
# INFO:gurobipy:Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
# INFO:gurobipy:
# INFO:gurobipy:Non-default parameters:
# INFO:gurobipy:MIPGap  0
# INFO:gurobipy:Method  1
# INFO:gurobipy:MIPFocus  3
# INFO:gurobipy:
# INFO:gurobipy:Optimize a model with 9819 rows, 8630 columns and 35023 nonzeros
# INFO:gurobipy:Model fingerprint: 0x406d6edb
# INFO:gurobipy:Variable types: 4476 continuous, 4154 integer (4054 binary)
# INFO:gurobipy:Coefficient statistics:
# INFO:gurobipy:  Matrix range     [2e-01, 3e+03]
# INFO:gurobipy:  Objective range  [1e+04, 1e+07]
# INFO:gurobipy:  Bounds range     [1e+00, 1e+00]
# INFO:gurobipy:  RHS range        [3e-01, 5e+02]
# INFO:gurobipy:
# INFO:gurobipy:User MIP start did not produce a new incumbent solution
# INFO:gurobipy:User MIP start violates constraint c_u_x18442_ by 1.000000000
# INFO:gurobipy:
# INFO:gurobipy:Presolve removed 8700 rows and 7735 columns
# INFO:gurobipy:Presolve time: 0.07s
# INFO:gurobipy:Presolved: 1119 rows, 895 columns, 3869 nonzeros
# INFO:gurobipy:Variable types: 496 continuous, 399 integer (398 binary)
# INFO:gurobipy:Found heuristic solution: objective 3.159608e+07
# INFO:gurobipy:Found heuristic solution: objective 3.157788e+07
# INFO:gurobipy:Found heuristic solution: objective 2.851438e+07
# INFO:gurobipy:Found heuristic solution: objective 2.365390e+07
# INFO:gurobipy:Root relaxation presolved: 1119 rows, 895 columns, 3869 nonzeros
# INFO:gurobipy:
# INFO:gurobipy:
# INFO:gurobipy:Root relaxation: objective 1.115766e+07, 572 iterations, 0.01 seconds (0.01 work units)
# INFO:gurobipy:Another try with MIP start
# INFO:gurobipy:
# INFO:gurobipy:    Nodes    |    Current Node    |     Objective Bounds      |     Work
# INFO:gurobipy: Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
# INFO:gurobipy:
# INFO:gurobipy:H    0     0                    1.338765e+07 1.1158e+07  16.7%     -    0s
# INFO:gurobipy:H    0     0                    1.327956e+07 1.1158e+07  16.0%     -    0s
# INFO:gurobipy:     0     0 1.1158e+07    0   32 1.3280e+07 1.1158e+07  16.0%     -    0s
# INFO:gurobipy:H    0     0                    1.322965e+07 1.1158e+07  15.7%     -    0s
# INFO:gurobipy:H    0     0                    1.312156e+07 1.1158e+07  15.0%     -    0s
# INFO:gurobipy:H    0     0                    1.301347e+07 1.1158e+07  14.3%     -    0s
# INFO:gurobipy:H    0     0                    1.268921e+07 1.1158e+07  12.1%     -    0s
# INFO:gurobipy:     0     0 1.2261e+07    0   46 1.2689e+07 1.2261e+07  3.37%     -    0s
# INFO:gurobipy:     0     0 1.2261e+07    0   31 1.2689e+07 1.2261e+07  3.37%     -    0s
# INFO:gurobipy:H    0     0                    1.258112e+07 1.2261e+07  2.54%     -    0s
# INFO:gurobipy:     0     0 1.2488e+07    0    9 1.2581e+07 1.2488e+07  0.74%     -    0s
# INFO:gurobipy:     0     0 1.2507e+07    0    8 1.2581e+07 1.2507e+07  0.59%     -    0s
# INFO:gurobipy:     0     0 1.2528e+07    0   11 1.2581e+07 1.2528e+07  0.42%     -    0s
# INFO:gurobipy:     0     0 1.2543e+07    0   14 1.2581e+07 1.2543e+07  0.31%     -    0s
# INFO:gurobipy:     0     0 1.2547e+07    0   19 1.2581e+07 1.2547e+07  0.27%     -    0s
# INFO:gurobipy:     0     0 1.2547e+07    0    9 1.2581e+07 1.2547e+07  0.27%     -    0s
# INFO:gurobipy:     0     0     cutoff    0      1.2581e+07 1.2581e+07  0.00%     -    0s
# INFO:gurobipy:
# INFO:gurobipy:Cutting planes:
# INFO:gurobipy:  Gomory: 11
# INFO:gurobipy:  Lift-and-project: 3
# INFO:gurobipy:  Implied bound: 2
# INFO:gurobipy:  Clique: 1
# INFO:gurobipy:  MIR: 15
# INFO:gurobipy:  Flow cover: 26
# INFO:gurobipy:
# INFO:gurobipy:Explored 1 nodes (1207 simplex iterations) in 0.37 seconds (0.20 work units)
# INFO:gurobipy:Thread count was 16 (of 16 available processors)
# INFO:gurobipy:
# INFO:gurobipy:Solution count 10: 1.25811e+07 1.25811e+07 1.26892e+07 ... 2.36539e+07
# INFO:gurobipy:
# INFO:gurobipy:Optimal solution found (tolerance 0.00e+00)
# INFO:gurobipy:Best objective 1.258111743500e+07, best bound 1.258111743500e+07, gap 0.0000%
# INFO:charger_location:Time for model solve 1: 1.03 seconds
# INFO:charger_location:Incumbent model has 11 queue prevention constraints
# INFO:charger_location:no index to delete
# INFO:gurobipy:Read LP format model from file C:\Users\chris\AppData\Local\Temp\tmpjdsfnc03.pyomo.lp
# INFO:gurobipy:Reading time = 0.05 seconds
# INFO:gurobipy:x1: 9821 rows, 8630 columns, 35031 nonzeros
# INFO:gurobipy:Read MIP start from file C:\Users\chris\AppData\Local\Temp\tmpt2pg40oh.gurobi.mst
# INFO:gurobipy:Set parameter MIPGap to value 0
# INFO:gurobipy:Set parameter MIPFocus to value 3
# INFO:gurobipy:Set parameter Method to value 1
# INFO:gurobipy:Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (win64 - Windows 11.0 (26100.2))
# INFO:gurobipy:
# INFO:gurobipy:CPU model: 13th Gen Intel(R) Core(TM) i5-13450HX, instruction set [SSE2|AVX|AVX2]
# INFO:gurobipy:Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
# INFO:gurobipy:
# INFO:gurobipy:Non-default parameters:
# INFO:gurobipy:MIPGap  0
# INFO:gurobipy:Method  1
# INFO:gurobipy:MIPFocus  3
# INFO:gurobipy:
# INFO:gurobipy:Optimize a model with 9821 rows, 8630 columns and 35031 nonzeros
# INFO:gurobipy:Model fingerprint: 0xc8a797b9
# INFO:gurobipy:Variable types: 4476 continuous, 4154 integer (4054 binary)
# INFO:gurobipy:Coefficient statistics:
# INFO:gurobipy:  Matrix range     [2e-01, 3e+03]
# INFO:gurobipy:  Objective range  [1e+04, 1e+07]
# INFO:gurobipy:  Bounds range     [1e+00, 1e+00]
# INFO:gurobipy:  RHS range        [3e-01, 5e+02]
# INFO:gurobipy:
# INFO:gurobipy:User MIP start did not produce a new incumbent solution
# INFO:gurobipy:User MIP start violates constraint c_u_x18451_ by 1.000000000
# INFO:gurobipy:
# INFO:gurobipy:Presolve removed 8706 rows and 7735 columns
# INFO:gurobipy:Presolve time: 0.06s
# INFO:gurobipy:Presolved: 1115 rows, 895 columns, 3865 nonzeros
# INFO:gurobipy:Variable types: 496 continuous, 399 integer (398 binary)
# INFO:gurobipy:Found heuristic solution: objective 3.159608e+07
# INFO:gurobipy:Found heuristic solution: objective 3.157788e+07
# INFO:gurobipy:Found heuristic solution: objective 2.838941e+07
# INFO:gurobipy:Found heuristic solution: objective 2.329585e+07
# INFO:gurobipy:Root relaxation presolved: 1115 rows, 895 columns, 3865 nonzeros
# INFO:gurobipy:
# INFO:gurobipy:
# INFO:gurobipy:Root relaxation: objective 1.115766e+07, 593 iterations, 0.01 seconds (0.01 work units)
# INFO:gurobipy:Another try with MIP start
# INFO:gurobipy:
# INFO:gurobipy:    Nodes    |    Current Node    |     Objective Bounds      |     Work
# INFO:gurobipy: Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
# INFO:gurobipy:
# INFO:gurobipy:H    0     0                    1.258112e+07 1.1158e+07  11.3%     -    0s
# INFO:gurobipy:     0     0 1.1158e+07    0   32 1.2581e+07 1.1158e+07  11.3%     -    0s
# INFO:gurobipy:     0     0 1.2261e+07    0   46 1.2581e+07 1.2261e+07  2.54%     -    0s
# INFO:gurobipy:     0     0 1.2261e+07    0   32 1.2581e+07 1.2261e+07  2.54%     -    0s
# INFO:gurobipy:     0     0 1.2517e+07    0    9 1.2581e+07 1.2517e+07  0.51%     -    0s
# INFO:gurobipy:     0     0 1.2525e+07    0   11 1.2581e+07 1.2525e+07  0.44%     -    0s
# INFO:gurobipy:     0     0 1.2537e+07    0    9 1.2581e+07 1.2537e+07  0.35%     -    0s
# INFO:gurobipy:     0     0 1.2547e+07    0   10 1.2581e+07 1.2547e+07  0.27%     -    0s
# INFO:gurobipy:     0     0 1.2577e+07    0   15 1.2581e+07 1.2577e+07  0.04%     -    0s
# INFO:gurobipy:     0     0 1.2581e+07    0   23 1.2581e+07 1.2581e+07  0.00%     -    0s
# INFO:gurobipy:
# INFO:gurobipy:Cutting planes:
# INFO:gurobipy:  Gomory: 19
# INFO:gurobipy:  Lift-and-project: 4
# INFO:gurobipy:  Implied bound: 4
# INFO:gurobipy:  MIR: 44
# INFO:gurobipy:  Mixing: 4
# INFO:gurobipy:  Flow cover: 39
# INFO:gurobipy:  Relax-and-lift: 2
# INFO:gurobipy:
# INFO:gurobipy:Explored 1 nodes (1145 simplex iterations) in 0.30 seconds (0.19 work units)
# INFO:gurobipy:Thread count was 16 (of 16 available processors)
# INFO:gurobipy:
# INFO:gurobipy:Solution count 7: 1.25811e+07 1.96272e+07 2.32959e+07 ... 3.15961e+07
# INFO:gurobipy:
# INFO:gurobipy:Optimal solution found (tolerance 0.00e+00)
# INFO:gurobipy:Best objective 1.258111743500e+07, best bound 1.258111743500e+07, gap 0.0000%
# INFO:charger_location:Time for model solve 2: 0.97 seconds
# INFO:charger_location:Incumbent model has 15 queue prevention constraints
# INFO:charger_location:no index to delete
# INFO:gurobipy:Read LP format model from file C:\Users\chris\AppData\Local\Temp\tmp1mmgj0e_.pyomo.lp
# INFO:gurobipy:Reading time = 0.03 seconds
# INFO:gurobipy:x1: 9825 rows, 8630 columns, 35043 nonzeros
# INFO:gurobipy:Read MIP start from file C:\Users\chris\AppData\Local\Temp\tmpozsm_3fj.gurobi.mst
# INFO:gurobipy:Set parameter MIPGap to value 0
# INFO:gurobipy:Set parameter MIPFocus to value 3
# INFO:gurobipy:Set parameter Method to value 1
# INFO:gurobipy:Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (win64 - Windows 11.0 (26100.2))
# INFO:gurobipy:
# INFO:gurobipy:CPU model: 13th Gen Intel(R) Core(TM) i5-13450HX, instruction set [SSE2|AVX|AVX2]
# INFO:gurobipy:Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
# INFO:gurobipy:
# INFO:gurobipy:Non-default parameters:
# INFO:gurobipy:MIPGap  0
# INFO:gurobipy:Method  1
# INFO:gurobipy:MIPFocus  3
# INFO:gurobipy:
# INFO:gurobipy:Optimize a model with 9825 rows, 8630 columns and 35043 nonzeros
# INFO:gurobipy:Model fingerprint: 0xcf70deae
# INFO:gurobipy:Variable types: 4476 continuous, 4154 integer (4054 binary)
# INFO:gurobipy:Coefficient statistics:
# INFO:gurobipy:  Matrix range     [2e-01, 3e+03]
# INFO:gurobipy:  Objective range  [1e+04, 1e+07]
# INFO:gurobipy:  Bounds range     [1e+00, 1e+00]
# INFO:gurobipy:  RHS range        [3e-01, 5e+02]
# INFO:gurobipy:
# INFO:gurobipy:User MIP start did not produce a new incumbent solution
# INFO:gurobipy:User MIP start violates constraint c_u_x18453_ by 1.000000000
# INFO:gurobipy:
# INFO:gurobipy:Presolve removed 8712 rows and 7735 columns
# INFO:gurobipy:Presolve time: 0.05s
# INFO:gurobipy:Presolved: 1113 rows, 895 columns, 3865 nonzeros
# INFO:gurobipy:Variable types: 496 continuous, 399 integer (398 binary)
# INFO:gurobipy:Found heuristic solution: objective 3.147110e+07
# INFO:gurobipy:Found heuristic solution: objective 3.146873e+07
# INFO:gurobipy:Found heuristic solution: objective 2.817323e+07
# INFO:gurobipy:Found heuristic solution: objective 2.329585e+07
# INFO:gurobipy:Root relaxation presolved: 1113 rows, 895 columns, 3865 nonzeros
# INFO:gurobipy:
# INFO:gurobipy:
# INFO:gurobipy:Root relaxation: objective 1.120064e+07, 564 iterations, 0.01 seconds (0.01 work units)
# INFO:gurobipy:Another try with MIP start
# INFO:gurobipy:
# INFO:gurobipy:    Nodes    |    Current Node    |     Objective Bounds      |     Work
# INFO:gurobipy: Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
# INFO:gurobipy:
# INFO:gurobipy:H    0     0                    1.338765e+07 1.1201e+07  16.3%     -    0s
# INFO:gurobipy:H    0     0                    1.268921e+07 1.1201e+07  11.7%     -    0s
# INFO:gurobipy:     0     0 1.1201e+07    0   33 1.2689e+07 1.1201e+07  11.7%     -    0s
# INFO:gurobipy:     0     0 1.2238e+07    0   45 1.2689e+07 1.2238e+07  3.55%     -    0s
# INFO:gurobipy:     0     0 1.2238e+07    0   31 1.2689e+07 1.2238e+07  3.55%     -    0s
# INFO:gurobipy:H    0     0                    1.258112e+07 1.2238e+07  2.73%     -    0s
# INFO:gurobipy:     0     0 1.2530e+07    0    7 1.2581e+07 1.2530e+07  0.41%     -    0s
# INFO:gurobipy:     0     0 1.2550e+07    0   13 1.2581e+07 1.2550e+07  0.25%     -    0s
# INFO:gurobipy:     0     0 1.2569e+07    0   12 1.2581e+07 1.2569e+07  0.09%     -    0s
# INFO:gurobipy:     0     0 1.2569e+07    0    9 1.2581e+07 1.2569e+07  0.09%     -    0s
# INFO:gurobipy:     0     0 1.2576e+07    0    3 1.2581e+07 1.2576e+07  0.04%     -    0s
# INFO:gurobipy:
# INFO:gurobipy:Cutting planes:
# INFO:gurobipy:  Learned: 1
# INFO:gurobipy:  Gomory: 15
# INFO:gurobipy:  Lift-and-project: 4
# INFO:gurobipy:  Cover: 3
# INFO:gurobipy:  Implied bound: 2
# INFO:gurobipy:  Clique: 2
# INFO:gurobipy:  MIR: 23
# INFO:gurobipy:  Flow cover: 26
# INFO:gurobipy:  Relax-and-lift: 1
# INFO:gurobipy:
# INFO:gurobipy:Explored 1 nodes (1209 simplex iterations) in 0.30 seconds (0.18 work units)
# INFO:gurobipy:Thread count was 16 (of 16 available processors)
# INFO:gurobipy:
# INFO:gurobipy:Solution count 10: 1.25811e+07 1.25811e+07 1.26892e+07 ... 3.14711e+07
# INFO:gurobipy:
# INFO:gurobipy:Optimal solution found (tolerance 0.00e+00)
# INFO:gurobipy:Best objective 1.258111743500e+07, best bound 1.258111743500e+07, gap 0.0000%
# INFO:charger_location:Time for model solve 3: 0.98 seconds
# INFO:charger_location:Time for complete model solve: 3.92 seconds

# %%
clm.log_results()
# Out:
# INFO:charger_location:Total number of backup buses used: 169
# INFO:charger_location:Optimal objective function value: 12581117.43
# INFO:charger_location:Optimal stations: ['3rd Avenue138th Street Station', 'Brooklyn College / Flatbush Avenue Terminal', 'Dyckman Street Station', 'Flushing  Main Street', 'Gateway Center (Near Spring Creek)', 'St. George Ferry Terminal', 'Staten Island Mall', 'Station 40']
# INFO:charger_location:Number of chargers: {'149th StreetGrand Concourse': 0, '161st StreetYankee Stadium Station': 0, '167th Street Station': 0, '174th175th Streets Station': 0, '182nd183rd Streets Station': 0, '207th Street Station': 0, '215th Street Station': 0, '3rd Avenue138th Street Station': 1, 'Atlantic Terminal': 0, 'Brooklyn College / Flatbush Avenue Terminal': 2, 'Bus Stops around LaGuardia Airport': 0, 'Co-op City Bay Plaza': 0, 'Coney Island  Stillwell Avenue Terminal': 0, 'Dyckman Street Station': 1, 'Eltingville Transit Center': 0, 'Far Rockaway  Mott Avenue': 0, 'Flushing  Main Street': 1, 'Fordham Plaza': 0, 'Gateway Center (Near Spring Creek)': 1, 'Jamaica Center  Parsons/Archer': 0, 'Kew Gardens  Union Tpke': 0, 'Near Kingsbridge Bus Depot': 0, 'Near Southern Boulevard Bus Depot': 0, 'Pelham Bay Park Station': 0, 'St. George Ferry Terminal': 1, 'Staten Island Mall': 2, 'Station 100': 0, 'Station 28': 0, 'Station 29': 0, 'Station 30': 0, 'Station 31': 0, 'Station 32': 0, 'Station 33': 0, 'Station 34': 0, 'Station 35': 0, 'Station 36': 0, 'Station 37': 0, 'Station 38': 0, 'Station 39': 0, 'Station 40': 1, 'Station 41': 0, 'Station 42': 0, 'Station 43': 0, 'Station 44': 0, 'Station 45': 0, 'Station 46': 0, 'Station 47': 0, 'Station 48': 0, 'Station 49': 0, 'Station 50': 0, 'Station 51': 0, 'Station 52': 0, 'Station 53': 0, 'Station 54': 0, 'Station 55': 0, 'Station 56': 0, 'Station 57': 0, 'Station 58': 0, 'Station 59': 0, 'Station 60': 0, 'Station 61': 0, 'Station 62': 0, 'Station 63': 0, 'Station 64': 0, 'Station 65': 0, 'Station 66': 0, 'Station 67': 0, 'Station 68': 0, 'Station 69': 0, 'Station 70': 0, 'Station 71': 0, 'Station 72': 0, 'Station 73': 0, 'Station 74': 0, 'Station 75': 0, 'Station 76': 0, 'Station 77': 0, 'Station 78': 0, 'Station 79': 0, 'Station 80': 0, 'Station 81': 0, 'Station 82': 0, 'Station 83': 0, 'Station 84': 0, 'Station 85': 0, 'Station 86': 0, 'Station 87': 0, 'Station 88': 0, 'Station 89': 0, 'Station 90': 0, 'Station 91': 0, 'Station 92': 0, 'Station 93': 0, 'Station 94': 0, 'Station 95': 0, 'Station 96': 0, 'Station 97': 0, 'Station 98': 0, 'Station 99': 0, 'Williamsburg Bridge Plaza Bus Terminal': 0}
# INFO:charger_location:Optimal number of charger visits: 47.0
# INFO:charger_location:Optimal total charging time: 465.10 minutes
# INFO:charger_location:Average time per charge: 9.90 minutes

# %%
clm.to_df()
# Out:
#      block_id                            trip_id  trip_idx  start_time  \
# 0    36441937  OH_A5-Weekday-SDon-023000_M15_205         1  65848550.0
# 1    36441937  OH_A5-Weekday-SDon-029000_M15_205         2  65848610.0
# 2    36441937  OH_A5-Weekday-SDon-035000_M15_205         3  65848670.0
# 3    36441937  OH_A5-Weekday-SDon-040700_M15_205         4  65848727.0
# 4    36441937  OH_A5-Weekday-SDon-049100_M15_205         5  65848811.0
# ..        ...                                ...       ...         ...
# 517  36879652                                100        23  65849466.0
# 518  36879662                                  0         0  65848747.0
# 519  36879662                                100        24  65849635.0
# 520  36879674                                  0         0  65848742.0
# 521  36879674                                100        12  65849158.0
#
#        end_time         soc                        chg_site  chg_time  \
# 0    65848600.0  293.272896                             NaN       NaN
# 1    65848657.0  260.578257                             NaN       NaN
# 2    65848721.0  234.714226                             NaN       NaN
# 3    65848791.0  212.262560  3rd Avenue138th Street Station  1.791611
# 4    65848896.0  197.110666                             NaN       NaN
# ..          ...         ...                             ...       ...
# 517  65849466.0   45.152741                             NaN       NaN
# 518  65848747.0  300.000000                             NaN       NaN
# 519  65849635.0   40.804363                             NaN       NaN
# 520  65848742.0  300.000000                             NaN       NaN
# 521  65849158.0   40.804363                             NaN       NaN
#
#           dh1       dh2       dh3
# 0         NaN       NaN       NaN
# 1         NaN       NaN       NaN
# 2         NaN       NaN       NaN
# 3    4.425333  4.641167  0.011355
# 4         NaN       NaN       NaN
# ..        ...       ...       ...
# 517       NaN       NaN       NaN
# 518       NaN       NaN       NaN
# 519       NaN       NaN       NaN
# 520       NaN       NaN       NaN
# 521       NaN       NaN       NaN
#
# [522 rows x 11 columns]

# %%
# clm.plot_chargers()

# %%
fig = plot_deadhead(
    result_df=clm.to_df(), loc_df=loc_df, coords_df=beb_trips
)
fig.show()
# Out:
# INFO:googlemaps.client:API queries_quota: 60
# INFO:googlemaps.client:API queries_quota: 60
# INFO:googlemaps.client:API queries_quota: 60
# INFO:googlemaps.client:API queries_quota: 60
# INFO:googlemaps.client:API queries_quota: 60
# INFO:googlemaps.client:API queries_quota: 60
# INFO:googlemaps.client:API queries_quota: 60
# INFO:googlemaps.client:API queries_quota: 60
# INFO:googlemaps.client:API queries_quota: 60
# INFO:googlemaps.client:API queries_quota: 60
# INFO:googlemaps.client:API queries_quota: 60
