# %% [markdown]
# # Library

# %%
from beb_chargers.scripts.script_helpers import build_trips_df, \
    build_charger_location_inputs
from beb_chargers.opt.charger_location import ChargerLocationModel
from beb_chargers.gtfs_beb import GTFSData
from beb_chargers.vis import plot_trips_and_terminals, plot_deadhead
from pathlib import Path
import datetime
import pandas as pd
import logging
logging.basicConfig(level=logging.INFO)

# %% [markdown]
# # Parameters

# %%
# Power output of each charger. Note that the model expects a unit of
# kilowatt-hours per minute, so that the amount of energy gained equals
# charging time (in minutes) multiplied by power (in kWh/min). Here, we
# use 450 kW = 450 / 60 kWh/min
chg_pwrs = 450 / 60

# Maximum number of chargers per site. We'll set it to 4 everywhere
n_max = 4

# Cost parameters. See TRC paper for where the values come from.
s_cost = 200000
c_cost = 698447
alpha = 190 * 365 * 12 / 60

# Locate CSV file giving candidate charger sites for this instance
site_fname = Path.cwd().parent / 'beb_chargers' / 'data' / 'test.csv'

# Load candidate charging sites given by Metro and add params as columns
loc_df = pd.read_csv(site_fname)
loc_df['max_chargers'] = n_max
loc_df['kw'] = chg_pwrs * 60
loc_df['fixed_cost'] = s_cost
loc_df['charger_cost'] = c_cost

# Define coordinates of overnight depot at South Base
depot_coords = (40.819197, -73.957060)

# %% [markdown]
# # Data

# %%
# Directory to GTFS files, as a platform-agnostic path
gtfs_dir = Path.cwd().parent / 'beb_chargers' / 'data' / 'gtfs' / 'GTFS'

# Load GTFS data into our custom object
gtfs = GTFSData.from_dir(gtfs_dir)

# %%
# Battery capacity in kWh
battery_cap = 300
# Energy consumption per mile for all buses (we'll assume it's the same
# for all buses here)
kwh_per_mi = 3

# %%
import csv
import random

# %%
import csv
import random

def read_routes_file(filename):
    """
    Reads the routes file and returns a list of route IDs that start with 'M'.
    
    Args:
        filename (str): Path to the CSV file containing route IDs.
    
    Returns:
        list: Filtered list of route IDs where the first letter is 'M'.
    """
    route_ids = []
    with open(filename, 'r', encoding='utf-8') as f:
        reader = csv.DictReader(f)
        for row in reader:
            if row['route_id'].startswith('M'):  # Filter routes that start with 'M'
                route_ids.append(row['route_id'])
    return route_ids

def random_select_routes(route_ids, percentage=1):
    """
    Randomly selects a subset of routes from the filtered list.
    
    Args:
        route_ids (list): List of filtered route IDs.
        percentage (float): Percentage of routes to select per iteration.
    
    Returns:
        list: Randomly selected route IDs.
    """
    num_to_select = round(len(route_ids) * percentage)
    return random.sample(route_ids, num_to_select) if route_ids else []

def main():
    filename = Path.cwd().parent / 'beb_chargers' / 'data' / 'gtfs' / 'GTFS' / 'routes.txt'
    num_iterations = 10  # Define the number of iterations
    
    route_ids = read_routes_file(filename)  # Read and filter routes
    print(f"Total number of routes starting with 'M': {len(route_ids)}")
    
    all_results = []
    
    for i in range(num_iterations):
        selected = random_select_routes(route_ids)  # Select 20% of the filtered routes
        all_results.append(selected)
        print(f"\nIteration {i+1}:")
        print(f"Selected {len(selected)} routes: {selected}")
    
    return all_results

if __name__ == "__main__":
    random.seed(42)  # Ensure reproducibility
    
    # Run the main process
    results = main()
    
    print("\nFinal 2D array of selected route_ids:")
    for i, row in enumerate(results):
        print(f"Row {i+1}: {row}")
# Out:
# Total number of routes starting with 'M': 48
#
# Iteration 1:
# Selected 48 routes: ['M72', 'M7', 'MQAS', 'M11', 'M104', 'M103', 'M8', 'M5', 'M42', 'M4', 'M57', 'M21', 'M1', 'M99', 'M60+', 'M102', 'M86+', 'M106', 'M12', 'MVAS', 'M98', 'M191', 'M14A+', 'M125', 'M15+', 'M55', 'M34A+', 'M90', 'M34+', 'M116', 'M79+', 'M22', 'M35', 'M100', 'M20', 'M96', 'M3', 'M50', 'M2', 'M101', 'M66', 'M31', 'M9', 'M141A', 'M10', 'M15', 'M14D+', 'M23+']
#
# Iteration 2:
# Selected 48 routes: ['M90', 'M23+', 'M42', 'M7', 'M15', 'M4', 'M50', 'M116', 'M66', 'M14D+', 'M55', 'M101', 'M3', 'M1', 'M103', 'M72', 'M86+', 'M21', 'M98', 'M31', 'M2', 'M57', 'M8', 'M35', 'M125', 'M100', 'M34+', 'M14A+', 'M60+', 'M5', 'M15+', 'M99', 'M141A', 'M11', 'M12', 'M22', 'M106', 'M191', 'M34A+', 'M79+', 'M20', 'M104', 'M102', 'MVAS', 'MQAS', 'M96', 'M10', 'M9']
#
# Iteration 3:
# Selected 48 routes: ['M11', 'M3', 'M102', 'M55', 'M125', 'M99', 'M79+', 'M34+', 'M15+', 'M23+', 'M9', 'M106', 'M8', 'M104', 'M98', 'M21', 'M66', 'M100', 'M7', 'M90', 'M35', 'M42', 'M1', 'M15', 'MQAS', 'M2', 'M22', 'M96', 'M4', 'M86+', 'M72', 'M101', 'M34A+', 'M57', 'M60+', 'M50', 'M141A', 'M20', 'MVAS', 'M14D+', 'M31', 'M5', 'M12', 'M191', 'M103', 'M10', 'M116', 'M14A+']
#
# Iteration 4:
# Selected 48 routes: ['M23+', 'MVAS', 'M106', 'M34A+', 'M100', 'M98', 'M5', 'M72', 'M12', 'M86+', 'M101', 'M9', 'M14D+', 'M10', 'M35', 'M90', 'M125', 'M104', 'M60+', 'M2', 'M96', 'M20', 'M15+', 'M55', 'M7', 'MQAS', 'M50', 'M116', 'M1', 'M66', 'M31', 'M34+', 'M3', 'M99', 'M42', 'M141A', 'M8', 'M103', 'M11', 'M21', 'M79+', 'M14A+', 'M15', 'M57', 'M102', 'M4', 'M22', 'M191']
#
# Iteration 5:
# Selected 48 routes: ['M35', 'M22', 'M7', 'M104', 'M103', 'M3', 'M141A', 'MQAS', 'M57', 'M50', 'M96', 'M66', 'MVAS', 'M86+', 'M2', 'M55', 'M42', 'M90', 'M72', 'M21', 'M10', 'M1', 'M106', 'M99', 'M8', 'M79+', 'M98', 'M5', 'M11', 'M34+', 'M14A+', 'M15', 'M12', 'M101', 'M125', 'M191', 'M23+', 'M100', 'M102', 'M4', 'M9', 'M34A+', 'M15+', 'M60+', 'M116', 'M14D+', 'M31', 'M20']
#
# Iteration 6:
# Selected 48 routes: ['M5', 'M104', 'M101', 'M99', 'M42', 'M22', 'M8', 'M21', 'M100', 'M11', 'M23+', 'M90', 'M3', 'M86+', 'M191', 'M2', 'MVAS', 'M1', 'M57', 'M15', 'M72', 'M7', 'M4', 'M102', 'M55', 'M14D+', 'M35', 'M98', 'MQAS', 'M15+', 'M125', 'M34+', 'M60+', 'M50', 'M14A+', 'M96', 'M20', 'M103', 'M141A', 'M79+', 'M66', 'M12', 'M9', 'M31', 'M116', 'M106', 'M10', 'M34A+']
#
# Iteration 7:
# Selected 48 routes: ['M2', 'M191', 'M57', 'M31', 'M34A+', 'M35', 'M10', 'M90', 'M96', 'M4', 'M100', 'M3', 'M55', 'M104', 'M15+', 'M7', 'M42', 'M116', 'M12', 'MQAS', 'M23+', 'M1', 'M102', 'M141A', 'M98', 'M14D+', 'M106', 'M79+', 'M8', 'M5', 'M125', 'M66', 'M21', 'M14A+', 'M20', 'M11', 'M101', 'M50', 'M15', 'M60+', 'M22', 'MVAS', 'M72', 'M99', 'M103', 'M34+', 'M86+', 'M9']
#
# Iteration 8:
# Selected 48 routes: ['M8', 'M14A+', 'M3', 'M104', 'M14D+', 'M116', 'M10', 'M22', 'M42', 'M12', 'M35', 'MVAS', 'M50', 'M60+', 'M5', 'M191', 'M106', 'M2', 'M72', 'M31', 'M96', 'M11', 'M99', 'M34A+', 'M9', 'M66', 'M57', 'M79+', 'M141A', 'M15', 'M34+', 'M98', 'M86+', 'M103', 'M102', 'M55', 'MQAS', 'M125', 'M90', 'M15+', 'M101', 'M7', 'M1', 'M100', 'M4', 'M21', 'M20', 'M23+']
#
# Iteration 9:
# Selected 48 routes: ['M50', 'MVAS', 'M7', 'M3', 'M9', 'M42', 'M1', 'M14D+', 'M57', 'M191', 'M96', 'M21', 'M8', 'M79+', 'M12', 'M72', 'M86+', 'M22', 'M100', 'M5', 'M141A', 'M99', 'M55', 'M2', 'M23+', 'M11', 'M102', 'M35', 'M98', 'M20', 'M4', 'M14A+', 'M15+', 'M90', 'M34+', 'M34A+', 'M106', 'M31', 'M15', 'M125', 'M104', 'M10', 'M101', 'M103', 'M66', 'M60+', 'MQAS', 'M116']
#
# Iteration 10:
# Selected 48 routes: ['M101', 'M23+', 'M14A+', 'M12', 'M103', 'M96', 'MQAS', 'M191', 'M15+', 'M141A', 'M11', 'M3', 'M57', 'M99', 'M34A+', 'M66', 'M60+', 'M31', 'MVAS', 'M2', 'M8', 'M4', 'M116', 'M21', 'M79+', 'M22', 'M98', 'M102', 'M100', 'M10', 'M125', 'M106', 'M42', 'M5', 'M9', 'M104', 'M55', 'M90', 'M86+', 'M35', 'M72', 'M1', 'M7', 'M15', 'M50', 'M20', 'M14D+', 'M34+']
#
# Final 2D array of selected route_ids:
# Row 1: ['M72', 'M7', 'MQAS', 'M11', 'M104', 'M103', 'M8', 'M5', 'M42', 'M4', 'M57', 'M21', 'M1', 'M99', 'M60+', 'M102', 'M86+', 'M106', 'M12', 'MVAS', 'M98', 'M191', 'M14A+', 'M125', 'M15+', 'M55', 'M34A+', 'M90', 'M34+', 'M116', 'M79+', 'M22', 'M35', 'M100', 'M20', 'M96', 'M3', 'M50', 'M2', 'M101', 'M66', 'M31', 'M9', 'M141A', 'M10', 'M15', 'M14D+', 'M23+']
# Row 2: ['M90', 'M23+', 'M42', 'M7', 'M15', 'M4', 'M50', 'M116', 'M66', 'M14D+', 'M55', 'M101', 'M3', 'M1', 'M103', 'M72', 'M86+', 'M21', 'M98', 'M31', 'M2', 'M57', 'M8', 'M35', 'M125', 'M100', 'M34+', 'M14A+', 'M60+', 'M5', 'M15+', 'M99', 'M141A', 'M11', 'M12', 'M22', 'M106', 'M191', 'M34A+', 'M79+', 'M20', 'M104', 'M102', 'MVAS', 'MQAS', 'M96', 'M10', 'M9']
# Row 3: ['M11', 'M3', 'M102', 'M55', 'M125', 'M99', 'M79+', 'M34+', 'M15+', 'M23+', 'M9', 'M106', 'M8', 'M104', 'M98', 'M21', 'M66', 'M100', 'M7', 'M90', 'M35', 'M42', 'M1', 'M15', 'MQAS', 'M2', 'M22', 'M96', 'M4', 'M86+', 'M72', 'M101', 'M34A+', 'M57', 'M60+', 'M50', 'M141A', 'M20', 'MVAS', 'M14D+', 'M31', 'M5', 'M12', 'M191', 'M103', 'M10', 'M116', 'M14A+']
# Row 4: ['M23+', 'MVAS', 'M106', 'M34A+', 'M100', 'M98', 'M5', 'M72', 'M12', 'M86+', 'M101', 'M9', 'M14D+', 'M10', 'M35', 'M90', 'M125', 'M104', 'M60+', 'M2', 'M96', 'M20', 'M15+', 'M55', 'M7', 'MQAS', 'M50', 'M116', 'M1', 'M66', 'M31', 'M34+', 'M3', 'M99', 'M42', 'M141A', 'M8', 'M103', 'M11', 'M21', 'M79+', 'M14A+', 'M15', 'M57', 'M102', 'M4', 'M22', 'M191']
# Row 5: ['M35', 'M22', 'M7', 'M104', 'M103', 'M3', 'M141A', 'MQAS', 'M57', 'M50', 'M96', 'M66', 'MVAS', 'M86+', 'M2', 'M55', 'M42', 'M90', 'M72', 'M21', 'M10', 'M1', 'M106', 'M99', 'M8', 'M79+', 'M98', 'M5', 'M11', 'M34+', 'M14A+', 'M15', 'M12', 'M101', 'M125', 'M191', 'M23+', 'M100', 'M102', 'M4', 'M9', 'M34A+', 'M15+', 'M60+', 'M116', 'M14D+', 'M31', 'M20']
# Row 6: ['M5', 'M104', 'M101', 'M99', 'M42', 'M22', 'M8', 'M21', 'M100', 'M11', 'M23+', 'M90', 'M3', 'M86+', 'M191', 'M2', 'MVAS', 'M1', 'M57', 'M15', 'M72', 'M7', 'M4', 'M102', 'M55', 'M14D+', 'M35', 'M98', 'MQAS', 'M15+', 'M125', 'M34+', 'M60+', 'M50', 'M14A+', 'M96', 'M20', 'M103', 'M141A', 'M79+', 'M66', 'M12', 'M9', 'M31', 'M116', 'M106', 'M10', 'M34A+']
# Row 7: ['M2', 'M191', 'M57', 'M31', 'M34A+', 'M35', 'M10', 'M90', 'M96', 'M4', 'M100', 'M3', 'M55', 'M104', 'M15+', 'M7', 'M42', 'M116', 'M12', 'MQAS', 'M23+', 'M1', 'M102', 'M141A', 'M98', 'M14D+', 'M106', 'M79+', 'M8', 'M5', 'M125', 'M66', 'M21', 'M14A+', 'M20', 'M11', 'M101', 'M50', 'M15', 'M60+', 'M22', 'MVAS', 'M72', 'M99', 'M103', 'M34+', 'M86+', 'M9']
# Row 8: ['M8', 'M14A+', 'M3', 'M104', 'M14D+', 'M116', 'M10', 'M22', 'M42', 'M12', 'M35', 'MVAS', 'M50', 'M60+', 'M5', 'M191', 'M106', 'M2', 'M72', 'M31', 'M96', 'M11', 'M99', 'M34A+', 'M9', 'M66', 'M57', 'M79+', 'M141A', 'M15', 'M34+', 'M98', 'M86+', 'M103', 'M102', 'M55', 'MQAS', 'M125', 'M90', 'M15+', 'M101', 'M7', 'M1', 'M100', 'M4', 'M21', 'M20', 'M23+']
# Row 9: ['M50', 'MVAS', 'M7', 'M3', 'M9', 'M42', 'M1', 'M14D+', 'M57', 'M191', 'M96', 'M21', 'M8', 'M79+', 'M12', 'M72', 'M86+', 'M22', 'M100', 'M5', 'M141A', 'M99', 'M55', 'M2', 'M23+', 'M11', 'M102', 'M35', 'M98', 'M20', 'M4', 'M14A+', 'M15+', 'M90', 'M34+', 'M34A+', 'M106', 'M31', 'M15', 'M125', 'M104', 'M10', 'M101', 'M103', 'M66', 'M60+', 'MQAS', 'M116']
# Row 10: ['M101', 'M23+', 'M14A+', 'M12', 'M103', 'M96', 'MQAS', 'M191', 'M15+', 'M141A', 'M11', 'M3', 'M57', 'M99', 'M34A+', 'M66', 'M60+', 'M31', 'MVAS', 'M2', 'M8', 'M4', 'M116', 'M21', 'M79+', 'M22', 'M98', 'M102', 'M100', 'M10', 'M125', 'M106', 'M42', 'M5', 'M9', 'M104', 'M55', 'M90', 'M86+', 'M35', 'M72', 'M1', 'M7', 'M15', 'M50', 'M20', 'M14D+', 'M34+']

# %%
results = main()
# Out:
# Total number of routes starting with 'M': 48
#
# Iteration 1:
# Selected 48 routes: ['M90', 'M12', 'M34A+', 'M191', 'M86+', 'M20', 'M125', 'M15+', 'M116', 'M50', 'M8', 'M101', 'M96', 'M15', 'M100', 'M98', 'M72', 'M11', 'M60+', 'MVAS', 'M9', 'M21', 'M5', 'M102', 'M66', 'M99', 'M79+', 'M10', 'M103', 'M14A+', 'M14D+', 'M34+', 'M104', 'M55', 'M31', 'M35', 'M1', 'M141A', 'MQAS', 'M3', 'M4', 'M22', 'M23+', 'M42', 'M7', 'M106', 'M57', 'M2']
#
# Iteration 2:
# Selected 48 routes: ['M1', 'M104', 'M31', 'M66', 'M3', 'M23+', 'M20', 'M72', 'M55', 'M101', 'M15', 'M34+', 'M15+', 'M90', 'M9', 'MVAS', 'M5', 'M57', 'M102', 'M7', 'M4', 'M50', 'M14A+', 'M106', 'M103', 'MQAS', 'M11', 'M22', 'M2', 'M14D+', 'M96', 'M116', 'M10', 'M60+', 'M125', 'M35', 'M100', 'M8', 'M98', 'M42', 'M86+', 'M79+', 'M21', 'M12', 'M141A', 'M99', 'M34A+', 'M191']
#
# Iteration 3:
# Selected 48 routes: ['M35', 'M34+', 'M72', 'M104', 'M11', 'M22', 'M3', 'M116', 'M98', 'M96', 'M141A', 'M125', 'M42', 'M4', 'M8', 'M9', 'M103', 'M101', 'M14A+', 'M79+', 'M23+', 'M5', 'M1', 'M102', 'M15', 'M10', 'M60+', 'M90', 'M14D+', 'MQAS', 'M20', 'M12', 'M31', 'M55', 'M66', 'M34A+', 'M100', 'MVAS', 'M106', 'M57', 'M7', 'M21', 'M15+', 'M50', 'M2', 'M99', 'M191', 'M86+']
#
# Iteration 4:
# Selected 48 routes: ['M103', 'M11', 'M21', 'M34+', 'MQAS', 'M15', 'M141A', 'M15+', 'M10', 'M23+', 'M8', 'M42', 'M96', 'M72', 'M50', 'M4', 'M99', 'M3', 'M98', 'M191', 'M34A+', 'M35', 'M57', 'M101', 'M66', 'M5', 'M22', 'M14D+', 'M125', 'M86+', 'M55', 'M102', 'M90', 'M106', 'M20', 'M7', 'MVAS', 'M104', 'M100', 'M60+', 'M2', 'M12', 'M9', 'M14A+', 'M31', 'M116', 'M1', 'M79+']
#
# Iteration 5:
# Selected 48 routes: ['M66', 'M9', 'M104', 'M8', 'M31', 'M86+', 'M7', 'M55', 'M102', 'M23+', 'M106', 'M14D+', 'M10', 'M79+', 'M50', 'M12', 'M5', 'M116', 'MVAS', 'M90', 'M96', 'M141A', 'M101', 'M15+', 'M14A+', 'M34+', 'M1', 'M21', 'M42', 'M2', 'M22', 'M125', 'MQAS', 'M4', 'M98', 'M72', 'M35', 'M103', 'M99', 'M191', 'M100', 'M60+', 'M57', 'M34A+', 'M15', 'M11', 'M20', 'M3']
#
# Iteration 6:
# Selected 48 routes: ['M99', 'M9', 'M21', 'M100', 'M35', 'M79+', 'M11', 'M66', 'M42', 'M31', 'M23+', 'M191', 'M86+', 'M125', 'M104', 'M4', 'M50', 'M22', 'M103', 'M7', 'M15', 'M57', 'M116', 'M12', 'M141A', 'M101', 'M10', 'MVAS', 'M96', 'M14D+', 'M34A+', 'M55', 'M5', 'M34+', 'M14A+', 'M3', 'M20', 'M102', 'M90', 'M15+', 'M72', 'M8', 'MQAS', 'M60+', 'M98', 'M1', 'M2', 'M106']
#
# Iteration 7:
# Selected 48 routes: ['M50', 'M104', 'M98', 'M31', 'M79+', 'M34+', 'M22', 'MQAS', 'M4', 'M116', 'M103', 'M15+', 'M90', 'M12', 'M14D+', 'M99', 'M14A+', 'M102', 'M35', 'M11', 'M10', 'M100', 'M86+', 'M57', 'M8', 'M9', 'M23+', 'M7', 'M2', 'M5', 'M21', 'M42', 'M66', 'M106', 'M15', 'M20', 'M125', 'M3', 'M55', 'M141A', 'M96', 'MVAS', 'M72', 'M1', 'M191', 'M34A+', 'M60+', 'M101']
#
# Iteration 8:
# Selected 48 routes: ['MVAS', 'M99', 'M42', 'M8', 'M11', 'M1', 'M2', 'M50', 'M116', 'M98', 'M34+', 'M5', 'M191', 'M66', 'M31', 'M35', 'M22', 'M10', 'M4', 'MQAS', 'M60+', 'M104', 'M79+', 'M86+', 'M101', 'M20', 'M15', 'M90', 'M57', 'M3', 'M125', 'M9', 'M141A', 'M15+', 'M12', 'M21', 'M55', 'M106', 'M34A+', 'M103', 'M100', 'M14D+', 'M7', 'M14A+', 'M23+', 'M102', 'M72', 'M96']
#
# Iteration 9:
# Selected 48 routes: ['M102', 'M72', 'M191', 'M106', 'M86+', 'M4', 'M10', 'M104', 'M100', 'M50', 'M3', 'M79+', 'MVAS', 'M20', 'M22', 'M31', 'M116', 'MQAS', 'M7', 'M9', 'M14A+', 'M35', 'M21', 'M103', 'M1', 'M141A', 'M23+', 'M8', 'M34+', 'M5', 'M99', 'M2', 'M15+', 'M55', 'M14D+', 'M57', 'M11', 'M34A+', 'M60+', 'M66', 'M101', 'M90', 'M96', 'M12', 'M125', 'M15', 'M42', 'M98']
#
# Iteration 10:
# Selected 48 routes: ['M98', 'M12', 'M191', 'M15+', 'M11', 'M34A+', 'M42', 'M34+', 'M22', 'M4', 'M1', 'M21', 'M125', 'M106', 'MQAS', 'M60+', 'M103', 'M31', 'M141A', 'M20', 'M55', 'M116', 'M66', 'MVAS', 'M23+', 'M8', 'M99', 'M35', 'M86+', 'M104', 'M79+', 'M72', 'M14A+', 'M57', 'M9', 'M5', 'M10', 'M7', 'M50', 'M100', 'M90', 'M2', 'M96', 'M14D+', 'M15', 'M101', 'M102', 'M3']

# %%
# All routes included in analysis
beb_routes = [
    'M1', 'M2', 'M3', 'M4', 'M5', 'M7', 'M8', 'M9', 'M10',
    'M100', 'M101', 'M102', 'M103', 'M104',
    'M14A-SBS', 'M14D-SBS', 'M15-SBS', 'M60-SBS',
    'Q30', 'Bx18B', 'Bx41-SBS', 'Bx36', 'B44-SBS',
    'B52', 'B74', 'X37', 'B111'
]
beb_routes = [str(r) for r in beb_routes]

beb_routes = results[0]

# %% [markdown]
# import csv
# import random
#
# def read_routes_file(filename):
#     """
#     Read routes file and return route_ids list
#     Args:
#         filename: CSV path
#     Returns:
#         route_ids list
#     """
#     route_ids = []
#     with open(filename, 'r', encoding='utf-8') as f:
#         reader = csv.DictReader(f)
#         for row in reader:
#             route_ids.append(row['route_id'])
#     return route_ids
#
# def filter_m_routes(route_ids):
#     """
#     Filter routes that start with 'M'
#     Args:
#         route_ids: list of all route IDs
#     Returns:
#         list of route IDs starting with 'M'
#     """
#     return [route for route in route_ids if route.startswith('M')]
#
# def random_select_routes_with_m_first(route_ids, percentage=0.1):
#     """
#     Select routes with first one being M-route
#     Args:
#         route_ids: all routes ID
#         percentage: percentage to select
#     Returns:
#         selected routes ID list starting with an M-route
#     """
#     # Separate M routes and non-M routes
#     m_routes = filter_m_routes(route_ids)
#     non_m_routes = [r for r in route_ids if not r.startswith('M')]
#
#     if not m_routes:
#         raise ValueError("No M-routes found in the input data")
#
#     # Calculate how many additional routes to select after M-route
#     total_to_select = round(len(route_ids) * percentage)
#     remaining_to_select = total_to_select - 1  # -1 because we'll select one M-route
#
#     # Select one M-route for the first position
#     selected_routes = [random.choice(m_routes)]
#
#     # Select remaining routes from all available routes (excluding the selected M-route)
#     available_routes = [r for r in route_ids if r != selected_routes[0]]
#
#     # Randomly select the remaining routes
#     for _ in range(remaining_to_select):
#         if not available_routes:
#             break
#         idx = random.randrange(len(available_routes))
#         selected_routes.append(available_routes.pop(idx))
#
#     return selected_routes
#
# def main():
#     filename = Path.cwd().parent / 'beb_chargers' / 'data' / 'gtfs' / 'GTFS' / 'routes.txt'
#     num_iterations = 10
#
#     route_ids = read_routes_file(filename)
#     print(f"Total number of routes: {len(route_ids)}")
#     print(f"Number of M-routes: {len(filter_m_routes(route_ids))}")
#
#     all_results = []
#
#     for i in range(num_iterations):
#         selected = random_select_routes_with_m_first(route_ids)
#         all_results.append(selected)
#         print(f"\nIteration {i+1}:")
#         print(f"Selected {len(selected)} routes: {selected}")
#         print(f"First route starts with 'M': {selected[0].startswith('M')}")
#
#     return all_results
#
# if __name__ == "__main__":
#     random.seed(42)
#
#     # Run main program
#     results = main()
#
#     print("\nFinal 2D array of selected route_ids:")
#     for i, row in enumerate(results):
#         print(f"Row {i+1}: {row}")

# %%
# We'll run analysis for March 28, 2024
ocl_date = datetime.datetime(2025, 3, 14)
# Call helper function to build up DF
beb_trips = build_trips_df(
    gtfs=gtfs,
    date=ocl_date,
    routes=beb_routes,
    depot_coords=depot_coords,
    add_depot_dh=True,
    add_kwh_per_mi=False,
    add_durations=False,
    routes_60=[]
)
# Add a column giving energy consumption for each trip
beb_trips['kwh_per_mi'] = kwh_per_mi

# %%
beb_trips
# Out:
#                                 trip_id route_id          service_id  \
# 0      OH_A5-Saturday-BM-141800_M15_201      M15   OH_A5-Saturday-BM
# 1       OH_A5-Saturday-BM-143500_M101_1     M103   OH_A5-Saturday-BM
# 2     MV_A5-Saturday-BM-139500_M104_101     M104   MV_A5-Saturday-BM
# 3     OH_A5-Weekday-SDon-006000_M15_201      M15  OH_A5-Weekday-SDon
# 4     OH_A5-Weekday-SDon-012000_M15_201      M15  OH_A5-Weekday-SDon
# ...                                 ...      ...                 ...
# 6188  KB_A5-Weekday-SDon-082400_M100_14     M100  KB_A5-Weekday-SDon
# 6189  KB_A5-Weekday-SDon-089400_M100_14     M100  KB_A5-Weekday-SDon
# 6190  KB_A5-Weekday-SDon-098400_M100_14     M100  KB_A5-Weekday-SDon
# 6191  KB_A5-Weekday-SDon-048000_M100_20     M100  KB_A5-Weekday-SDon
# 6192  KB_A5-Weekday-SDon-055600_M100_20     M100  KB_A5-Weekday-SDon
#
#       block_id  shape_id route  route_type                   route_desc  \
# 0     36440938   M150023   M15           3          via 1st Av / 2nd Av
# 1     36441011  M1030040  M103           3    via 3rd Av / Lexington Av
# 2     36441665  M1040167  M104           3        via Broadway / 8th Av
# 3     36441933   M150044   M15           3          via 1st Av / 2nd Av
# 4     36441933   M150023   M15           3          via 1st Av / 2nd Av
# ...        ...       ...   ...         ...                          ...
# 6188  36466228  M1000107  M100           3  via Broadway / Amsterdam Av
# 6189  36466228  M1000113  M100           3  via Broadway / Amsterdam Av
# 6190  36466228  M1000107  M100           3  via Broadway / Amsterdam Av
# 6191  36466229  M1000113  M100           3  via Broadway / Amsterdam Av
# 6192  36466229  M1000107  M100           3  via Broadway / Amsterdam Av
#
#               start_time            end_time  trip_idx  start_lat  start_lon  \
# 0    2025-03-14 23:38:00 2025-03-15 00:39:00         0  40.803182 -73.932486
# 1    2025-03-14 23:55:00 2025-03-15 00:37:00         0  40.803858 -73.937786
# 2    2025-03-14 23:15:00 2025-03-14 23:56:00         0  40.814222 -73.953091
# 3    2025-03-14 01:00:00 2025-03-14 01:43:00         0  40.701481 -74.012461
# 4    2025-03-14 02:00:00 2025-03-14 02:46:00         1  40.803182 -73.932486
# ...                  ...                 ...       ...        ...        ...
# 6188 2025-03-14 13:44:00 2025-03-14 14:44:00         1  40.810959 -73.953041
# 6189 2025-03-14 14:54:00 2025-03-14 16:04:00         2  40.872558 -73.912473
# 6190 2025-03-14 16:24:00 2025-03-14 17:27:00         3  40.810959 -73.953041
# 6191 2025-03-14 08:00:00 2025-03-14 09:01:00         0  40.872558 -73.912473
# 6192 2025-03-14 09:16:00 2025-03-14 10:09:00         1  40.810959 -73.953041
#
#         end_lat    end_lon  total_dist  duration_sched  60_dummy  kwh_per_mi
# 0     40.701549 -74.012199   20.429058            61.0         0           3
# 1     40.711699 -74.007341   18.179389            42.0         0           3
# 2     40.756384 -73.989832   11.766449            41.0         0           3
# 3     40.803102 -73.932299   18.574302            43.0         0           3
# 4     40.701549 -74.012199    8.641575            46.0         0           3
# ...         ...        ...         ...             ...       ...         ...
# 6188  40.872464 -73.912582    5.885478            60.0         0           3
# 6189  40.810293 -73.952930    6.224719            70.0         0           3
# 6190  40.872464 -73.912582   12.180382            63.0         0           3
# 6191  40.810293 -73.952930   12.784091            61.0         0           3
# 6192  40.872464 -73.912582   12.180382            53.0         0           3
#
# [6193 rows x 19 columns]

# %%
# Record how many trips and blocks are active on our specified routes on this day
logging.info(
    '{}: There are {} total trips to be served by {} BEB blocks.'.format(
        ocl_date.strftime('%m/%d/%y'), len(beb_trips), beb_trips['block_id'].nunique()
    )
)
# Out:
# INFO:root:03/14/25: There are 6193 total trips to be served by 699 BEB blocks.

# %%
# Create a map of the problem instance
inst_map = plot_trips_and_terminals(
    beb_trips, loc_df, gtfs.shapes_df, 'light'
)
# These config params make map downloads higher resolution
config = {
    'toImageButtonOptions': {
        'format': 'png',
        'scale': 3
    }
}
inst_map.show(config=config)

# %%
opt_kwargs = build_charger_location_inputs(
    gtfs=gtfs,
    trips_df=beb_trips,
    chargers_df=loc_df,
    depot_coords=depot_coords,
    battery_cap=battery_cap
)
# Out:
# INFO:gtfs_data:OSM request: 48 origins, 37 destinations (1776 total routes)
# INFO:gtfs_data:OpenRouteService matrix returned in 1.01 seconds.
# INFO:gtfs_data:OSM request: 37 origins, 53 destinations (1961 total routes)
# INFO:gtfs_data:OpenRouteService matrix returned in 0.99 seconds.

# %%
# this is the dictionary
type (opt_kwargs)
# Out:
# dict

# %%
# Create instance of charger location model based on those inputs
clm = ChargerLocationModel(**opt_kwargs)
# Solve the model with zero optimality gap
clm.solve(alpha=alpha, opt_gap=0, bu_kwh=battery_cap)
# Out:
# INFO:charger_location:Number of blocks that require charging: 71
# INFO:charger_location:Number of trips in charging blocks: 1192
# INFO:charger_location:Number of infeasible blocks: 4
# INFO:charger_location:Infeasible block IDs: ['36443130', '36443131', '36443133', '36443135']
# INFO:charger_location:Number of trips in infeasible blocks: 82
# INFO:charger_location:Time for heuristic runs: 0.31 seconds
# INFO:charger_location:Average number of backups: 2.06
# INFO:charger_location:Minimum number of backups: 2
#
# INFO:charger_location:Mean Conflict set size: 7.90
# INFO:gurobipy:Read LP format model from file C:\Users\chris\AppData\Local\Temp\tmpuqd64n84.pyomo.lp
# INFO:gurobipy:Reading time = 0.07 seconds
# INFO:gurobipy:x1: 22219 rows, 19516 columns, 82211 nonzeros
# INFO:gurobipy:Set parameter MIPGap to value 0
# INFO:gurobipy:Set parameter MIPFocus to value 3
# INFO:gurobipy:Set parameter Method to value 1
# INFO:gurobipy:Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (win64 - Windows 11.0 (26100.2))
# INFO:gurobipy:
# INFO:gurobipy:CPU model: 13th Gen Intel(R) Core(TM) i5-13450HX, instruction set [SSE2|AVX|AVX2]
# INFO:gurobipy:Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
# INFO:gurobipy:
# INFO:gurobipy:Non-default parameters:
# INFO:gurobipy:MIPGap  0
# INFO:gurobipy:Method  1
# INFO:gurobipy:MIPFocus  3
# INFO:gurobipy:
# INFO:gurobipy:Optimize a model with 22219 rows, 19516 columns and 82211 nonzeros
# INFO:gurobipy:Model fingerprint: 0xdb389318
# INFO:gurobipy:Variable types: 10209 continuous, 9307 integer (9207 binary)
# INFO:gurobipy:Coefficient statistics:
# INFO:gurobipy:  Matrix range     [2e-04, 3e+03]
# INFO:gurobipy:  Objective range  [3e+04, 1e+07]
# INFO:gurobipy:  Bounds range     [1e+00, 1e+00]
# INFO:gurobipy:  RHS range        [3e-01, 3e+02]
# INFO:gurobipy:Presolve removed 16025 rows and 14287 columns
# INFO:gurobipy:Presolve time: 0.18s
# INFO:gurobipy:Presolved: 6194 rows, 5229 columns, 23257 nonzeros
# INFO:gurobipy:Variable types: 2820 continuous, 2409 integer (2409 binary)
# INFO:gurobipy:Found heuristic solution: objective 8.407312e+07
# INFO:gurobipy:Found heuristic solution: objective 7.397471e+07
# INFO:gurobipy:Found heuristic solution: objective 7.197825e+07
# INFO:gurobipy:Found heuristic solution: objective 7.196892e+07
# INFO:gurobipy:Root relaxation presolve removed 12 rows and 13 columns
# INFO:gurobipy:Root relaxation presolved: 6182 rows, 5216 columns, 23243 nonzeros
# INFO:gurobipy:
# INFO:gurobipy:
# INFO:gurobipy:Root relaxation: objective 4.267297e+06, 3146 iterations, 0.06 seconds (0.05 work units)
# INFO:gurobipy:
# INFO:gurobipy:    Nodes    |    Current Node    |     Objective Bounds      |     Work
# INFO:gurobipy: Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
# INFO:gurobipy:
# INFO:gurobipy:     0     0 4267297.33    0  179 7.1969e+07 4267297.33  94.1%     -    0s
# INFO:gurobipy:H    0     0                    6.927358e+07 4267297.33  93.8%     -    0s
# INFO:gurobipy:H    0     0                    6.884811e+07 4267297.33  93.8%     -    0s
# INFO:gurobipy:H    0     0                    6.700406e+07 4267297.33  93.6%     -    0s
# INFO:gurobipy:H    0     0                    1.161056e+07 4267297.33  63.2%     -    0s
# INFO:gurobipy:H    0     0                    1.042158e+07 4267297.33  59.1%     -    0s
# INFO:gurobipy:H    0     0                    1.035667e+07 4808871.34  53.6%     -    0s
# INFO:gurobipy:H    0     0                    1.003241e+07 4808871.34  52.1%     -    0s
# INFO:gurobipy:H    0     0                    9924316.3933 4808871.34  51.5%     -    0s
# INFO:gurobipy:     0     0 7958744.01    0  292 9924316.39 7958744.01  19.8%     -    1s
# INFO:gurobipy:     0     0 8667444.97    0  297 9924316.39 8667444.97  12.7%     -    1s
# INFO:gurobipy:     0     0 8667444.97    0  297 9924316.39 8667444.97  12.7%     -    1s
# INFO:gurobipy:     0     0 9563114.12    0  269 9924316.39 9563114.12  3.64%     -    1s
# INFO:gurobipy:     0     0 9567225.92    0  329 9924316.39 9567225.92  3.60%     -    2s
# INFO:gurobipy:     0     0 9567225.92    0  321 9924316.39 9567225.92  3.60%     -    2s
# INFO:gurobipy:     0     0 9567225.92    0  323 9924316.39 9567225.92  3.60%     -    2s
# INFO:gurobipy:     0     0 9593566.18    0  327 9924316.39 9593566.18  3.33%     -    2s
# INFO:gurobipy:     0     0 9820440.32    0  181 9924316.37 9820440.32  1.05%     -   24s
# INFO:gurobipy:     0     0 9820440.32    0   49 9924316.37 9820440.32  1.05%     -   25s
# INFO:gurobipy:     0     0 9820440.32    0  196 9924316.37 9820440.32  1.05%     -   25s
# INFO:gurobipy:     0     0 9820837.46    0  230 9924316.37 9820837.46  1.04%     -   25s
# INFO:gurobipy:     0     0 9822242.98    0  251 9924316.37 9822242.98  1.03%     -   25s
# INFO:gurobipy:     0     0 9822326.44    0  250 9924316.37 9822326.44  1.03%     -   26s
# INFO:gurobipy:     0     2 9822326.44    0  250 9924316.37 9822326.44  1.03%     -   26s
# INFO:gurobipy:
# INFO:gurobipy:Cutting planes:
# INFO:gurobipy:  Gomory: 68
# INFO:gurobipy:  Lift-and-project: 8
# INFO:gurobipy:  Cover: 32
# INFO:gurobipy:  Implied bound: 25
# INFO:gurobipy:  MIR: 229
# INFO:gurobipy:  Mixing: 31
# INFO:gurobipy:  StrongCG: 2
# INFO:gurobipy:  Flow cover: 383
# INFO:gurobipy:  Inf proof: 1
# INFO:gurobipy:  Zero half: 95
# INFO:gurobipy:  Relax-and-lift: 6
# INFO:gurobipy:
# INFO:gurobipy:Explored 1086 nodes (99285 simplex iterations) in 28.29 seconds (24.59 work units)
# INFO:gurobipy:Thread count was 16 (of 16 available processors)
# INFO:gurobipy:
# INFO:gurobipy:Solution count 10: 9.92432e+06 9.92432e+06 9.92432e+06 ... 6.88481e+07
# INFO:gurobipy:
# INFO:gurobipy:Optimal solution found (tolerance 0.00e+00)
# INFO:gurobipy:Best objective 9.924316367767e+06, best bound 9.924316367767e+06, gap 0.0000%
# INFO:charger_location:Time for initial model solve: 29.38 seconds
# INFO:charger_location:Incumbent model has 29 queue prevention constraints
# INFO:gurobipy:Read LP format model from file C:\Users\chris\AppData\Local\Temp\tmpfdagjxyq.pyomo.lp
# INFO:gurobipy:Reading time = 0.07 seconds
# INFO:gurobipy:x1: 22248 rows, 19516 columns, 82365 nonzeros
# INFO:gurobipy:Read MIP start from file C:\Users\chris\AppData\Local\Temp\tmpdjde4wpf.gurobi.mst
# INFO:gurobipy:Set parameter MIPGap to value 0
# INFO:gurobipy:Set parameter MIPFocus to value 3
# INFO:gurobipy:Set parameter Method to value 1
# INFO:gurobipy:Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (win64 - Windows 11.0 (26100.2))
# INFO:gurobipy:
# INFO:gurobipy:CPU model: 13th Gen Intel(R) Core(TM) i5-13450HX, instruction set [SSE2|AVX|AVX2]
# INFO:gurobipy:Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
# INFO:gurobipy:
# INFO:gurobipy:Non-default parameters:
# INFO:gurobipy:MIPGap  0
# INFO:gurobipy:Method  1
# INFO:gurobipy:MIPFocus  3
# INFO:gurobipy:
# INFO:gurobipy:Optimize a model with 22248 rows, 19516 columns and 82365 nonzeros
# INFO:gurobipy:Model fingerprint: 0x64d64013
# INFO:gurobipy:Variable types: 10209 continuous, 9307 integer (9207 binary)
# INFO:gurobipy:Coefficient statistics:
# INFO:gurobipy:  Matrix range     [2e-04, 3e+03]
# INFO:gurobipy:  Objective range  [3e+04, 1e+07]
# INFO:gurobipy:  Bounds range     [1e+00, 1e+00]
# INFO:gurobipy:  RHS range        [3e-01, 3e+02]
# INFO:gurobipy:
# INFO:gurobipy:User MIP start did not produce a new incumbent solution
# INFO:gurobipy:User MIP start violates constraint c_u_x41737_ by 1.000000000
# INFO:gurobipy:
# INFO:gurobipy:Presolve removed 16118 rows and 14285 columns
# INFO:gurobipy:Presolve time: 0.19s
# INFO:gurobipy:Presolved: 6130 rows, 5231 columns, 23218 nonzeros
# INFO:gurobipy:Variable types: 2820 continuous, 2411 integer (2409 binary)
# INFO:gurobipy:Found heuristic solution: objective 8.317141e+07
# INFO:gurobipy:Found heuristic solution: objective 8.316845e+07
# INFO:gurobipy:Found heuristic solution: objective 7.816867e+07
# INFO:gurobipy:Found heuristic solution: objective 7.192825e+07
# INFO:gurobipy:Found heuristic solution: objective 7.192574e+07
# INFO:gurobipy:Root relaxation presolve removed 10 rows and 10 columns
# INFO:gurobipy:Root relaxation presolved: 6120 rows, 5221 columns, 23202 nonzeros
# INFO:gurobipy:
# INFO:gurobipy:
# INFO:gurobipy:Root relaxation: objective 4.302240e+06, 3162 iterations, 0.05 seconds (0.05 work units)
# INFO:gurobipy:
# INFO:gurobipy:    Nodes    |    Current Node    |     Objective Bounds      |     Work
# INFO:gurobipy: Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
# INFO:gurobipy:
# INFO:gurobipy:     0     0 4302240.33    0  178 7.1926e+07 4302240.33  94.0%     -    0s
# INFO:gurobipy:Another try with MIP start
# INFO:gurobipy:H    0     0                    1.397046e+07 4302240.33  69.2%     -    0s
# INFO:gurobipy:H    0     0                    1.342777e+07 4302240.33  68.0%     -    0s
# INFO:gurobipy:H    0     0                    1.325110e+07 4302240.33  67.5%     -    0s
# INFO:gurobipy:H    0     0                    1.259923e+07 4302240.33  65.9%     -    0s
# INFO:gurobipy:H    0     0                    1.248736e+07 4302240.33  65.5%     -    0s
# INFO:gurobipy:H    0     0                    1.248104e+07 4302240.33  65.5%     -    0s
# INFO:gurobipy:H    0     0                    1.140718e+07 4302240.33  62.3%     -    0s
# INFO:gurobipy:     0     0 9981529.43    0  139 1.0002e+07 9981529.43  0.21%     -   25s
# INFO:gurobipy:     0     0 9985515.52    0  136 1.0002e+07 9985515.52  0.17%     -   25s
# INFO:gurobipy:     0     0 9985547.33    0   69 1.0002e+07 9985547.33  0.17%     -   26s
# INFO:gurobipy:     0     0 9985547.33    0  100 1.0002e+07 9985547.33  0.17%     -   26s
# INFO:gurobipy:     0     0 9985867.08    0  101 1.0002e+07 9985867.08  0.16%     -   26s
# INFO:gurobipy:     0     0 9985877.37    0  101 1.0002e+07 9985877.37  0.16%     -   26s
# INFO:gurobipy:     0     0 9988803.48    0  114 1.0002e+07 9988803.48  0.13%     -   26s
# INFO:gurobipy:     0     0 9988803.48    0   58 1.0002e+07 9988803.48  0.13%     -   26s
# INFO:gurobipy:     0     0 9988803.48    0   79 1.0002e+07 9988803.48  0.13%     -   26s
# INFO:gurobipy:     0     0 9988803.48    0   79 1.0002e+07 9988803.48  0.13%     -   26s
# INFO:gurobipy:     0     0 9989960.09    0   82 1.0002e+07 9989960.09  0.12%     -   26s
# INFO:gurobipy:     0     0 9989960.09    0   83 1.0002e+07 9989960.09  0.12%     -   26s
# INFO:gurobipy:     0     0 9989960.09    0   83 1.0002e+07 9989960.09  0.12%     -   26s
# INFO:gurobipy:     0     0 9989983.12    0   89 1.0002e+07 9989983.12  0.12%     -   26s
# INFO:gurobipy:     0     0 9993098.88    0   87 1.0002e+07 9993098.88  0.09%     -   26s
# INFO:gurobipy:     0     0 9993098.88    0   86 1.0002e+07 9993098.88  0.09%     -   26s
# INFO:gurobipy:     0     0 9993104.19    0   86 1.0002e+07 9993104.19  0.09%     -   26s
# INFO:gurobipy:
# INFO:gurobipy:Cutting planes:
# INFO:gurobipy:  Gomory: 32
# INFO:gurobipy:  Cover: 18
# INFO:gurobipy:  Implied bound: 33
# INFO:gurobipy:  Projected implied bound: 4
# INFO:gurobipy:  Clique: 8
# INFO:gurobipy:  MIR: 109
# INFO:gurobipy:  Mixing: 5
# INFO:gurobipy:  Flow cover: 180
# INFO:gurobipy:  Zero half: 34
# INFO:gurobipy:  RLT: 1
# INFO:gurobipy:  Relax-and-lift: 5
# INFO:gurobipy:  BQP: 3
# INFO:gurobipy:
# INFO:gurobipy:Explored 1 nodes (73763 simplex iterations) in 26.56 seconds (20.62 work units)
# INFO:gurobipy:Thread count was 16 (of 16 available processors)
# INFO:gurobipy:
# INFO:gurobipy:Solution count 10: 1.00022e+07 1.00022e+07 1.00022e+07 ... 1.00163e+07
# INFO:gurobipy:
# INFO:gurobipy:Optimal solution found (tolerance 0.00e+00)
# INFO:gurobipy:Best objective 1.000218488051e+07, best bound 1.000218488051e+07, gap 0.0000%
# INFO:charger_location:Time for model solve 3: 27.75 seconds
# INFO:charger_location:Incumbent model has 89 queue prevention constraints
# INFO:charger_location:no index to delete
# INFO:gurobipy:Read LP format model from file C:\Users\chris\AppData\Local\Temp\tmpadp1_xn9.pyomo.lp
# INFO:gurobipy:Reading time = 0.11 seconds
# INFO:gurobipy:x1: 22308 rows, 19516 columns, 82655 nonzeros
# INFO:gurobipy:Read MIP start from file C:\Users\chris\AppData\Local\Temp\tmptu1szmcz.gurobi.mst
# INFO:gurobipy:Set parameter MIPGap to value 0
# INFO:gurobipy:Set parameter MIPFocus to value 3
# INFO:gurobipy:Set parameter Method to value 1
# INFO:gurobipy:Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (win64 - Windows 11.0 (26100.2))
# INFO:gurobipy:
# INFO:gurobipy:CPU model: 13th Gen Intel(R) Core(TM) i5-13450HX, instruction set [SSE2|AVX|AVX2]
# INFO:gurobipy:Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
# INFO:gurobipy:
# INFO:gurobipy:Non-default parameters:
# INFO:gurobipy:MIPGap  0
# INFO:gurobipy:Method  1
# INFO:gurobipy:MIPFocus  3
# INFO:gurobipy:
# INFO:gurobipy:Optimize a model with 22308 rows, 19516 columns and 82655 nonzeros
# INFO:gurobipy:Model fingerprint: 0x880c62e6
# INFO:gurobipy:Variable types: 10209 continuous, 9307 integer (9207 binary)
# INFO:gurobipy:Coefficient statistics:
# INFO:gurobipy:  Matrix range     [2e-04, 3e+03]
# INFO:gurobipy:  Objective range  [3e+04, 1e+07]
# INFO:gurobipy:  Bounds range     [1e+00, 1e+00]
# INFO:gurobipy:  RHS range        [3e-01, 3e+02]
# INFO:gurobipy:
# INFO:gurobipy:User MIP start did not produce a new incumbent solution
# INFO:gurobipy:User MIP start violates constraint c_u_x41815_ by 1.000000000
# INFO:gurobipy:
# INFO:gurobipy:Presolve removed 16279 rows and 14284 columns
# INFO:gurobipy:Presolve time: 0.21s
# INFO:gurobipy:Presolved: 6029 rows, 5232 columns, 23173 nonzeros
# INFO:gurobipy:Variable types: 2820 continuous, 2412 integer (2409 binary)
# INFO:gurobipy:Found heuristic solution: objective 8
# INFO:gurobipy:     0     0 9817818.17    0  269 1.0047e+07 9817818.17  2.28%     -    7s
# INFO:gurobipy:     0     0 9817818.17    0  262 1.0047e+07 9817818.17  2.28%     -    7s
# INFO:gurobipy:     0     0 9817818.17    0  311 1.0047e+07 9817818.17  2.28%     -    8s
# INFO:gurobipy:     0     0 9817818.17    0  269 1.0047e+07 9817818.17  2.28%     -    8s
# INFO:gurobipy:     0     0 9834270.78    0  371 1.0047e+07 9834270.78  2.12%     -    9s
# INFO:gurobipy:     0     0 9845413.20    0  370 1.0047e+07 9845413.20  2.01%     -   10s
# INFO:gurobipy:     0     0 9845413.20    0  369 1.0047e+07 9845413.20  2.01%     -   10s
# INFO:gurobipy:     0     0 9856141.91    0  360 1.0047e+07 9856141.91  1.90%     -   10s
# INFO:gurobipy:     0     0 9858787.24    0  357 1.0047e+07 9858787.24  1.88%     -   11s
# INFO:gurobipy:     0     2 9858787.24    0  357 1.0047e+07 9858787.24  1.88%     -   11s
# INFO:gurobipy:  1315   941 1.0030e+07   18    2 1.0047e+07 1.0010e+07  0.37%  20.1   15s
# INFO:gurobipy:
# INFO:gurobipy:Cutting planes:
# INFO:gurobipy:  Gomory: 53
# INFO:gurobipy:  Lift-and-project: 1
# INFO:gurobipy:  Cover: 55
# INFO:gurobipy:  Implied bound: 18
# INFO:gurobipy:  Dual implied bound: 1
# INFO:gurobipy:  MIR: 471
# INFO:gurobipy:  Mixing: 17
# INFO:gurobipy:  StrongCG: 4
# INFO:gurobipy:  Flow cover: 525
# INFO:gurobipy:  Inf proof: 3
# INFO:gurobipy:  Zero half: 107
# INFO:gurobipy:  Relax-and-lift: 3
# INFO:gurobipy:
# INFO:gurobipy:Explored 4209 nodes (77441 simplex iterations) in 17.99 seconds (14.75 work units)
# INFO:gurobipy:Thread count was 16 (of 16 available processors)
# INFO:gurobipy:
# INFO:gurobipy:Solution count 10: 1.00473e+07 1.01554e+07 1.01941e+07 ... 1.05897e+07
# INFO:gurobipy:
# INFO:gurobipy:Optimal solution found (tolerance 0.00e+00)
# INFO:gurobipy:Best objective 1.004727394333e+07, best bound 1.004727394333e+07, gap 0.0000%
# INFO:charger_location:Time for model solve 13: 18.82 seconds
# INFO:charger_location:Incumbent model has 149 queue prevention constraints
# INFO:charger_location:no index to delete
# INFO:gurobipy:Read LP format model from file C:\Users\chris\AppData\Local\Temp\tmp3h0jfi37.pyomo.lp
# INFO:gurobipy:Reading time = 0.06 seconds
# INFO:gurobipy:x1: 22368 rows, 19516 columns, 82925 nonzeros
# INFO:gurobipy:Read MIP start from file C:\Users\chris\AppData\Local\Temp\tmp8ogfht4n.gurobi.mst
# INFO:gurobipy:Set parameter MIPGap to value 0
# INFO:gurobipy:Set parameter MIPFocus to value 3
# INFO:gurobipy:Set parameter Method to value 1
# INFO:gurobipy:Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (win64 - Windows 11.0 (26100.2))
# INFO:gurobipy:
# INFO:gurobipy:CPU model: 13th Gen Intel(R) Core(TM) i5-13450HX, instruction set [SSE2|AVX|AVX2]
# INFO:gurobipy:Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
# INFO:gurobipy:
# INFO:gurobipy:Non-default parameters:
# INFO:gurobipy:MIPGap  0
# INFO:gurobipy:Method  1
# INFO:gurobipy:MIPFocus  3
# INFO:gurobipy:
# INFO:gurobipy:Optimize a model with 22368 rows, 19516 columns and 82925 nonzeros
# INFO:gurobipy:Model fingerprint: 0xb16ddfce
# INFO:gurobipy:Variable types: 10209 continuous, 9307 integer (9207 binary)
# INFO:gurobipy:Coefficient statistics:
# INFO:gurobipy:  Matrix range     [2e-04, 3e+03]
# INFO:gurobipy:  Objective range  [3e+04, 1e+07]
# INFO:gurobipy:  Bounds range     [1e+00, 1e+00]
# INFO:gurobipy:  RHS range        [3e-01, 3e+02]
# INFO:gurobipy:
# INFO:gurobipy:User MIP start did not produce a new incumbent solution
# INFO:gurobipy:User MIP start violates constraint c_u_x41883_ by 1.000000000
# INFO:gurobipy:
# INFO:gurobipy:Presolve removed 16152 rows and 14284 columns
# INFO:gurobipy:Presolve time: 0.13s
# INFO:gurobipy:Presolved: 6216 rows, 5232 columns, 23690 nonzeros
# INFO:gurobipy:Variable types: 2820 continuous, 2412 integer (2409 binary)
# INFO:gurobipy:Found heuristic solution: objective 8.169838e+07
# INFO:gurobipy:Found heuristic solution: objective 8.169429e+07
# INFO:gurobipy:Found heuristic solution: objective 7.881767e+07
# INFO:gurobipy:Found heuristic solution: objective 7.322334e+07
# INFO:gurobipy:Found heuristic solution: objective 7.319926e+07
# INFO:gurobipy:Root relaxation presolve removed 296 rows and 11 columns
# INFO:gurobipy:Root relaxation presolved: 5920 rows, 5221 columns, 23102 nonzeros
# INFO:gurobipy:
# INFO:gurobipy:
# INFO:gurobipy:Root relaxation: objective 4.362931e+06, 3145 iterations, 0.04 seconds (0.05 work units)
# INFO:gurobipy:Another try with MIP start
# INFO:gurobipy:
# INFO:gurobipy:    Nodes    |    Current Node    |     Objective Bounds      |     Work
# INFO:gurobipy: Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
# INFO:gurobipy:
# INFO:gurobipy:H    0     0                    1.195386e+07 4362930.56  63.5%     -    0s
# INFO:gurobipy:H    0     0                    1.181401e+07 4362930.56  63.1%     -    0s
# INFO:gurobipy:H    0     0                    1.179435e+07 4362930.56  63.0%     -    0s
# INFO:gurobipy:H    0     0                    1.168747e+07 4362930.56  62.7%     -    0s
# INFO:gurobipy:H    0     0                    1.158694e+07 4362930.56  62.3%     -    0s
# INFO:gurobipy:H    0     0                    1.157951e+07 4362930.56  62.3%     -    0s
# INFO:gurobipy:H    0     0                    1.150908e+07 4362930.56  62.1%     -    0s
# INFO:gurobipy:H    0     0                    1.149403e+07 4362930.56  62.0%     -    0s
# INFO:gurobipy:H    0     0                    1.135921e+07 4362930.56  61.6%     -    0s
# INFO:gurobipy:H    0     0                    1.135289e+07 4362930.56  61.6%     -    0s
# INFO:gurobipy:H    0     0                    1.061568e+07 4362930.56  58.9%     -    0s
# INFO:gurobipy:     0     0 4362930.56    0  174 1.0616e+07 4362930.56  58.9%     -    0s
# INFO:gurobipy:H    0     0                    1.060936e+07 4362930.56  58.9%     -    0s
# INFO:gurobipy:H    0     0                    1.059430e+07 4362930.56  58.8%     -    0s
# INFO:gurobipy:     0     0 8593079.96    0  328 1.0594e+07 8593079.96  18.9%     -    1s
# INFO:gurobipy:   109    87 9962386.10   12   13 1.0047e+07 9947481.03  0.99%  51.9   10s
# INFO:gurobipy:H  113    87                    1.004727e+07 9951313.13  0.96%  50.4   10s
# INFO:gurobipy:
# INFO:gurobipy:Cutting planes:
# INFO:gurobipy:  Gomory: 48
# INFO:gurobipy:  Lift-and-project: 17
# INFO:gurobipy:  Cover: 45
# INFO:gurobipy:  Implied bound: 20
# INFO:gurobipy:  Projected implied bound: 3
# INFO:gurobipy:  Dual implied bound: 1
# INFO:gurobipy:  MIR: 344
# INFO:gurobipy:  Mixing: 19
# INFO:gurobipy:  StrongCG: 7
# INFO:gurobipy:  Flow cover: 490
# INFO:gurobipy:  Inf proof: 2
# INFO:gurobipy:  Zero half: 70
# INFO:gurobipy:  Relax-and-lift: 2
# INFO:gurobipy:
# INFO:gurobipy:Explored 1299 nodes (39522 simplex iterations) in 11.82 seconds (9.81 work units)
# INFO:gurobipy:Thread count was 16 (of 16 available processors)
# INFO:gurobipy:
# INFO:gurobipy:Solution count 10: 1.00473e+07 1.00473e+07 1.00473e+07 ... 1.05943e+07
# INFO:gurobipy:
# INFO:gurobipy:Optimal solution found (tolerance 0.00e+00)
# INFO:gurobipy:Best objective 1.004727393329e+07, best bound 1.004727393329e+07, gap 0.0000%
# INFO:charger_location:Time for model solve 14: 12.85 seconds
# INFO:charger_location:Time for complete model solve: 296.26 seconds

# %%
clm.log_results()
# Out:
# INFO:charger_location:Total number of backup buses used: 2
# INFO:charger_location:Optimal objective function value: 10047273.93
# INFO:charger_location:Optimal stations: ['207th Street Station', '3rd Avenue138th Street Station']
# INFO:charger_location:Number of chargers: {'149th StreetGrand Concourse': 0, '161st StreetYankee Stadium Station': 0, '167th Street Station': 0, '174th175th Streets Station': 0, '182nd183rd Streets Station': 0, '207th Street Station': 1, '215th Street Station': 0, '3rd Avenue138th Street Station': 1, 'Atlantic Terminal': 0, 'Brooklyn College / Flatbush Avenue Terminal': 0, 'Bus Stops around LaGuardia Airport': 0, 'Co-op City Bay Plaza': 0, 'Coney Island  Stillwell Avenue Terminal': 0, 'Dyckman Street Station': 0, 'Eltingville Transit Center': 0, 'Far Rockaway  Mott Avenue': 0, 'Flushing  Main Street': 0, 'Fordham Plaza': 0, 'Gateway Center (Near Spring Creek)': 0, 'Jamaica Center  Parsons/Archer': 0, 'Kew Gardens  Union Tpke': 0, 'Near Kingsbridge Bus Depot': 0, 'Near Southern Boulevard Bus Depot': 0, 'Pelham Bay Park Station': 0, 'St. George Ferry Terminal': 0, 'Staten Island Mall': 0, 'Station 100': 0, 'Station 28': 0, 'Station 29': 0, 'Station 30': 0, 'Station 31': 0, 'Station 32': 0, 'Station 33': 0, 'Station 34': 0, 'Station 35': 0, 'Station 36': 0, 'Station 37': 0, 'Station 38': 0, 'Station 39': 0, 'Station 40': 0, 'Station 41': 0, 'Station 42': 0, 'Station 43': 0, 'Station 44': 0, 'Station 45': 0, 'Station 46': 0, 'Station 47': 0, 'Station 48': 0, 'Station 49': 0, 'Station 50': 0, 'Station 51': 0, 'Station 52': 0, 'Station 53': 0, 'Station 54': 0, 'Station 55': 0, 'Station 56': 0, 'Station 57': 0, 'Station 58': 0, 'Station 59': 0, 'Station 60': 0, 'Station 61': 0, 'Station 62': 0, 'Station 63': 0, 'Station 64': 0, 'Station 65': 0, 'Station 66': 0, 'Station 67': 0, 'Station 68': 0, 'Station 69': 0, 'Station 70': 0, 'Station 71': 0, 'Station 72': 0, 'Station 73': 0, 'Station 74': 0, 'Station 75': 0, 'Station 76': 0, 'Station 77': 0, 'Station 78': 0, 'Station 79': 0, 'Station 80': 0, 'Station 81': 0, 'Station 82': 0, 'Station 83': 0, 'Station 84': 0, 'Station 85': 0, 'Station 86': 0, 'Station 87': 0, 'Station 88': 0, 'Station 89': 0, 'Station 90': 0, 'Station 91': 0, 'Station 92': 0, 'Station 93': 0, 'Station 94': 0, 'Station 95': 0, 'Station 96': 0, 'Station 97': 0, 'Station 98': 0, 'Station 99': 0, 'Williamsburg Bridge Plaza Bus Terminal': 0}
# INFO:charger_location:Optimal number of charger visits: 81.0
# INFO:charger_location:Optimal total charging time: 637.72 minutes
# INFO:charger_location:Average time per charge: 7.87 minutes

# %%
clm.to_df()
# Out:
#       block_id                            trip_id  trip_idx  start_time  \
# 0     36441937  OH_A5-Weekday-SDon-023000_M15_205         1  65848550.0
# 1     36441937  OH_A5-Weekday-SDon-029000_M15_205         2  65848610.0
# 2     36441937  OH_A5-Weekday-SDon-035000_M15_205         3  65848670.0
# 3     36441937  OH_A5-Weekday-SDon-040700_M15_205         4  65848727.0
# 4     36441937  OH_A5-Weekday-SDon-049100_M15_205         5  65848811.0
# ...        ...                                ...       ...         ...
# 1097  36466220                                100        15  65849547.0
# 1098  36466221                                  0         0  65848560.0
# 1099  36466221                                100        15  65849510.0
# 1100  36466226                                  0         0  65848620.0
# 1101  36466226                                100        15  65849577.0
#
#         end_time         soc chg_site  chg_time  dh1  dh2  dh3
# 0     65848600.0  293.272896      NaN       NaN  NaN  NaN  NaN
# 1     65848657.0  260.578257      NaN       NaN  NaN  NaN  NaN
# 2     65848721.0  234.714226      NaN       NaN  NaN  NaN  NaN
# 3     65848791.0  212.262560      NaN       NaN  NaN  NaN  NaN
# 4     65848896.0  190.297151      NaN       NaN  NaN  NaN  NaN
# ...          ...         ...      ...       ...  ...  ...  ...
# 1097  65849547.0   22.571407      NaN       NaN  NaN  NaN  NaN
# 1098  65848560.0  300.000000      NaN       NaN  NaN  NaN  NaN
# 1099  65849510.0   45.071407      NaN       NaN  NaN  NaN  NaN
# 1100  65848620.0  300.000000      NaN       NaN  NaN  NaN  NaN
# 1101  65849577.0   22.710186      NaN       NaN  NaN  NaN  NaN
#
# [1102 rows x 11 columns]

# %%
# clm.plot_chargers()

# %%
fig = plot_deadhead(
    result_df=clm.to_df(), loc_df=loc_df, coords_df=beb_trips
)
fig.show()
# Out:
# INFO:googlemaps.client:API queries_quota: 60
# INFO:googlemaps.client:API queries_quota: 60
# INFO:googlemaps.client:API queries_quota: 60
# INFO:googlemaps.client:API queries_quota: 60
# INFO:googlemaps.client:API queries_quota: 60
# INFO:googlemaps.client:API queries_quota: 60
# INFO:googlemaps.client:API queries_quota: 60
# INFO:googlemaps.client:API queries_quota: 60
# INFO:googlemaps.client:API queries_quota: 60
# INFO:googlemaps.client:API queries_quota: 60
# INFO:googlemaps.client:API queries_quota: 60
# INFO:googlemaps.client:API queries_quota: 60
# INFO:googlemaps.client:API queries_quota: 60
